# %% [markdown]
# Problem 2: Movie Data Analysis ( *hw0_p2.py* )
#
# In this homework, you are asked to write a program for answering the following questions based on IMDB Movie data ( *IMDB‐Movie‐Data.csv* ).
#
# You are required to write a function for answering each question. You may want to use `Python’s File reading`, `List`, `Dictionary`, and `Functions`.
#
# **You cannot use any packages**. The output format of each question is free.

# %%
class MyTable:
    
    def __init__(self):
        with open('IMDB-Movie-Data.csv', 'r') as f:
            self.contents = [line for line in f]
            self.columns_names = self.contents[0].strip('\n').split(',')
            self.rows = [content.strip('\n').split(',') for content in self.contents[1:]]
    
    def describe(self):
        print(f'data\'s length without titles: {len(self.rows)}')
        print(f'Columns name: \n{self.columns_names}')
    
    def __repr__(self):
        text = ''
        for line in self.contents:
            text += line + '\n'
        return text
    
    def columns(self, col_name: str) -> list:
        assert col_name in self.columns_names, f'choose column from {self.columns_names}'
        
        col_index = self.columns_names.index(col_name)
        return [row[col_index] for row in self.rows]
    
    def multi_col_name_index(self, *col_name) -> list:
        col_names = []
        for i in col_name:
            assert i in self.columns_names, f'choose column from {self.columns_names}'
            col_names.append(i)
        
        return [df.columns_names.index(col_names[i]) for i in range(len(col_names))]
            
    def rows_with_column(self, col_name: str, data_type: str) -> list:
        assert col_name in self.columns_names, f'choose column from {self.columns_names}'
        
        col_index = self.columns_names.index(col_name)
        return [i for i in df.rows if i[col_index] == data_type]

    def total_revenue(self):
        count_total = lambda df: sum(float(i) for i in df if i != '')
        total_revenue = round(count_total(df.columns(col_name='Revenue (Millions)')), 2)
        return total_revenue

# %%
df = MyTable()
#df.describe()

# %% [markdown]
# ## (1) Top-3 movies with the highest ratings in 2016?

# %% [markdown]
# ##### check

# %%
#print(len([i for i in df.rows_with_column(col_name='Year', data_type='2016')]), '\n')
#print('checking with first three:\n',[i for i in df.rows_with_column(col_name='Year', data_type='2016')][0:3])

# %% [markdown]
# ##### answer

# %%
df_2016_sorted = sorted(df.rows_with_column(col_name='Year', data_type='2016'), key=lambda x: int(x[0]))
df_2016_top3 = [each_movie[df.columns_names.index('Title')] for each_movie in df_2016_sorted[:3]]
print(f'Top-3 movies with the highest ratings in 2016: {df_2016_top3}\n')
# Out:
# Top-3 movies with the highest ratings in 2016: ['Split', 'Sing', 'Suicide Squad']

# %% [markdown]
# ## (2) The actor generating the highest average revenue?

# %% [markdown]
# - 有最高平均薪酬的演員？
# - 每部戲賺的錢 / 戲裡的演員 = 平均薪酬
# - 找出平均薪酬裡最高的演員？
#
# ？是這樣嗎？

# %% [markdown]
# ##### 有被紀錄revenue的戲的數量

# %%
count_have_revenue = 0
for i in df.columns(col_name='Revenue (Millions)'):
    if i != '':
        count_have_revenue += 1
#count_have_revenue

# %% [markdown]
# ##### 每位演員演過多少部戲

# %%
#每部戲出現的演員
actors = [j.strip() 
          for i in [actors.split('|') for actors in df.columns('Actors')] 
          for j in i]
#print(len(actors))

actors_count =  {}
for person in actors:
    if person not in actors_count:
        actors_count[person] = 1
    else:
        actors_count[person] += 1
#print(actors_count)

# %%
#len(actors_count)

# %%
actors_count_sorted = {k: v for k, v in sorted(actors_count.items(), key=lambda item: item[1], reverse=True)}
#print(actors_count_sorted)

# %% [markdown]
# ##### answer
# ##### 每部戲讓演員們平均賺多少錢

# %%
index_T_A_R = df.multi_col_name_index('Title', 'Actors', 'Revenue (Millions)')
t_a_r = [(i[index_T_A_R[0]], i[index_T_A_R[1]], i[index_T_A_R[2]]) for i in df.rows if i[index_T_A_R[2]] != '']
highest_avg_money = 0
movie = ''
who = ''
for i in t_a_r:
    #print(i, '\n')
    person_count = 1
    money = float(i[2])
    for j in i[1]:
        if j == '|':
            person_count += 1
    each = money / person_count
    if each > highest_avg_money:
        highest_avg_money = each
        movie = i[0]
        who = i[1]

print('The actor generating the highest average revenue:')
print(f'highest average money: {highest_avg_money}, {who}\n')
print(person_count)
# Out:
# The actor generating the highest average revenue:
# highest average money: 234.1575, Daisy Ridley| John Boyega| Oscar Isaac| Domhnall Gleeson
#
# 4

# %%
person_count
# Out:
# 4

# %% [markdown]
# ## (3) The average rating of Emma Watson’s movies?

# %% [markdown]
# - 她有演過多少部戲？
# - 她演過的戲的rank的加總？再平均

# %% [markdown]
# ##### check

# %%
actors = [j.strip() 
          for i in [actors.split('|') for actors in df.columns('Actors')] 
          for j in i]
#print(f'{len(actors)} actors in total of all movies')
#print('Emma Watson' in actors)
#print(f"{actors_count['Emma Watson']} movies by Emma Watson")

# %%
for movie in [actors.split('|') for actors in df.columns('Actors')]:
    #print(movie)
    for person in movie:
        if person.strip() == 'Emma Watson':
            #print(person)
            pass

# %%
test_str = 'Christian Bale| Heath Ledger| Aaron Eckhart|Michael Caine'
#print('Christian Bale' in test_str)

# %% [markdown]
# ##### answer

# %%
index_R_T_A = df.multi_col_name_index('Rank', 'Title', 'Actors')
r_t_a = [(i[index_R_T_A[0]], i[index_R_T_A[1]], i[index_R_T_A[2]]) for i in df.rows]

emma_watson_movies = [(rank, title) for rank, title, actor in r_t_a if 'Emma Watson' in actor]
#print(emma_watson_movies, '\n')
print(f"The average rating of Emma Watson’s movies: {sum(int(rank) for rank, title in emma_watson_movies) / actors_count['Emma Watson']}\n")
# Out:
# The average rating of Emma Watson’s movies: 437.5

# %% [markdown]
# ## (4) Top-3 directors who collaborate with the most actors?

# %% [markdown]
# ##### check

# %%
#print(f"director in {len(df.columns(col_name='Director'))} of movies")
#print([director for director in df.columns(col_name='Director')][0:3])

# %%
director_repeat = [director for director in df.columns(col_name='Director')]
director_nonrepeat = []
for d in director_repeat:
    if d not in director_nonrepeat:
        director_nonrepeat.append(d)
#print(len(director_repeat))
#print(len(director_nonrepeat))

# %%
index_d, index_a = df.multi_col_name_index('Director', 'Actors')
d_a = []
for i in df.rows:
    i[index_a] = i[index_a].replace('|', ',')
    i[index_a] = i[index_a].replace(', ', ',')
    d_a.append((i[index_d], i[index_a]))
#d_a[0]

# %%
collaborate = []
for da in d_a:
    for a in da[1].split(','):
        collaborate.append((da[0], a))
#print(collaborate)

# %% [markdown]
# ##### check

# %%
def director_work_with(target_director: str) -> list:
    return [actor
        for director, actor in collaborate
        if director == target_director]

def director_work_with_how_many(target_director: str) -> int:
    count_a = []
    for a in director_work_with(target_director):
        if a not in count_a:
            count_a.append(a)
    return len(count_a)

#director_work_with_how_many('Christopher Nolan')

# %% [markdown]
# ##### answer

# %%
all_director_with_with_how_many = []
for d in director_nonrepeat:
    director = ''
    count_collaborate = director_work_with_how_many(d)
    highest_collaborate = count_collaborate
    director = d
    all_director_with_with_how_many.append((director, highest_collaborate))

#all_director_with_with_how_many

# %%
all_director_with_with_how_many = sorted(all_director_with_with_how_many, key=lambda x: x[1], reverse=True)
print(f'Top-3 directors who collaborate with the most actors:\n{[i[0] for i in all_director_with_with_how_many[:3]]}\n')
# Out:
# Top-3 directors who collaborate with the most actors:
# ['Ridley Scott', 'M. Night Shyamalan', 'Danny Boyle']

# %% [markdown]
# # (5) Top-2 actors playing in the most genres of movies?

# %%
index_g, index_a = df.multi_col_name_index('Genre', 'Actors')
g_a = []
for i in df.rows:
    i[index_a] = i[index_a].replace('|', ',')
    i[index_a] = i[index_a].replace(', ', ',')
    i[index_g] = i[index_g].replace('|', ',')
    g_a.append((i[index_g], i[index_a]))
g_a[0]
# Out:
# ('Action,Crime,Drama',
#  'Christian Bale,Heath Ledger,Aaron Eckhart,Michael Caine')

# %%
actor_genre = {}
for genres, actors in g_a:
    for actor in actors.split(','):
        if actor not in actor_genre:
            actor_genre[actor] = []
            for genre in genres.split(','):
                actor_genre[actor].append(genre)
        else:
            for genre in genres.split(','):
                if genre not in actor_genre[actor]:
                    actor_genre[actor].append(genre)
actor_genre
# Out:
# {'Christian Bale': ['Action',
#   'Crime',
#   'Drama',
#   'Mystery',
#   'Sci-Fi',
#   'Thriller',
#   'Biography',
#   'Comedy',
#   'Adventure',
#   'History',
#   'Romance'],
#  'Heath Ledger': ['Action',
#   'Crime',
#   'Drama',
#   'Adventure',
#   'Fantasy',
#   'Mystery'],
#  'Aaron Eckhart': ['Action',
#   'Crime',
#   'Drama',
#   'Biography',
#   'Sport',
#   'Thriller'],
#  'Michael Caine': ['Action',
#   'Crime',
#   'Drama',
#   'Mystery',
#   'Sci-Fi',
#   'Thriller',
#   'Adventure',
#   'Comedy',
#   'Music',
#   'Animation'],
#  'Leonardo DiCaprio': ['Action',
#   'Adventure',
#   'Sci-Fi',
#   'Crime',
#   'Drama',
#   'Thriller',
#   'Western',
#   'Biography',
#   'Comedy',
#   'Mystery',
#   'Romance'],
#  'Joseph Gordon-Levitt': ['Action',
#   'Adventure',
#   'Sci-Fi',
#   'Comedy',
#   'Drama',
#   'Romance',
#   'Biography',
#   'History',
#   'Crime',
#   'Thriller'],
#  'Ellen Page': ['Action',
#   'Adventure',
#   'Sci-Fi',
#   'Comedy',
#   'Drama',
#   'Romance',
#   'Thriller'],
#  'Ken Watanabe': ['Action', 'Adventure', 'Sci-Fi', 'Drama'],
#  'Aamir Khan': ['Action',
#   'Biography',
#   'Drama',
#   'Family',
#   'Music',
#   'Comedy',
#   'Romance'],
#  'Sakshi Tanwar': ['Action', 'Biography', 'Drama'],
#  'Fatima Sana Shaikh': ['Action', 'Biography', 'Drama'],
#  'Sanya Malhotra': ['Action', 'Biography', 'Drama'],
#  'Matthew McConaughey': ['Adventure',
#   'Drama',
#   'Sci-Fi',
#   'Biography',
#   'Comedy',
#   'Crime',
#   'Animation',
#   'Family',
#   'Action',
#   'Thriller'],
#  'Anne Hathaway': ['Adventure',
#   'Drama',
#   'Sci-Fi',
#   'Action',
#   'Thriller',
#   'Musical',
#   'Romance',
#   'Comedy',
#   'Animation',
#   'Family',
#   'Fantasy'],
#  'Jessica Chastain': ['Adventure',
#   'Drama',
#   'Sci-Fi',
#   'History',
#   'Thriller',
#   'Fantasy',
#   'Horror',
#   'Action'],
#  'Mackenzie Foy': ['Adventure', 'Drama', 'Sci-Fi'],
#  'Ryunosuke Kamiki': ['Animation', 'Drama', 'Fantasy'],
#  'Mone Kamishiraishi': ['Animation', 'Drama', 'Fantasy'],
#  'Ryo Narita': ['Animation', 'Drama', 'Fantasy'],
#  'Aoi Yuki': ['Animation', 'Drama', 'Fantasy', 'Romance'],
#  'Francois Cluzet': ['Biography', 'Comedy', 'Drama'],
#  'Omar Sy': ['Biography', 'Comedy', 'Drama'],
#  'Anne Le Ny': ['Biography', 'Comedy', 'Drama'],
#  'Audrey Fleurot': ['Biography', 'Comedy', 'Drama'],
#  'Hugh Jackman': ['Drama',
#   'Mystery',
#   'Sci-Fi',
#   'Crime',
#   'Action',
#   'Adventure',
#   'Musical',
#   'Romance',
#   'Biography',
#   'Comedy',
#   'Family',
#   'Fantasy',
#   'Animation'],
#  'Scarlett Johansson': ['Drama',
#   'Mystery',
#   'Sci-Fi',
#   'Action',
#   'Romance',
#   'Adventure',
#   'Comedy',
#   'Animation',
#   'Family',
#   'Biography',
#   'History',
#   'Thriller',
#   'Horror'],
#  'Matt Damon': ['Crime',
#   'Drama',
#   'Thriller',
#   'Action',
#   'Mystery',
#   'Adventure',
#   'Sci-Fi',
#   'Western',
#   'Romance',
#   'Fantasy'],
#  'Jack Nicholson': ['Crime', 'Drama', 'Thriller'],
#  'Mark Wahlberg': ['Crime',
#   'Drama',
#   'Thriller',
#   'Action',
#   'Biography',
#   'History',
#   'Comedy',
#   'Fantasy',
#   'Adventure',
#   'Romance',
#   'Family',
#   'Sci-Fi'],
#  'Tom Hardy': ['Action',
#   'Thriller',
#   'Drama',
#   'Sport',
#   'Adventure',
#   'Sci-Fi',
#   'Crime',
#   'Biography',
#   'Mystery',
#   'Comedy',
#   'Romance'],
#  'Gary Oldman': ['Action',
#   'Thriller',
#   'Adventure',
#   'Drama',
#   'Mystery',
#   'Crime',
#   'Sci-Fi'],
#  'Miles Teller': ['Drama',
#   'Music',
#   'Comedy',
#   'Crime',
#   'Romance',
#   'Biography',
#   'Sport',
#   'Action',
#   'Adventure',
#   'Sci-Fi'],
#  'J.K. Simmons': ['Drama',
#   'Music',
#   'Comedy',
#   'History',
#   'Thriller',
#   'Action',
#   'Crime',
#   'Animation',
#   'Adventure'],
#  'Melissa Benoist': ['Drama', 'Music'],
#  'Paul Reiser': ['Drama', 'Music'],
#  'Ulrich Muhe': ['Drama', 'Thriller'],
#  'Martina Gedeck': ['Drama', 'Thriller'],
#  'Sebastian Koch': ['Drama', 'Thriller'],
#  'Ulrich Tukur': ['Drama', 'Thriller'],
#  'Darsheel Safary': ['Drama', 'Family', 'Music'],
#  'Tanay Chheda': ['Drama', 'Family', 'Music'],
#  'Sachet Engineer': ['Drama', 'Family', 'Music'],
#  'Jamie Foxx': ['Drama',
#   'Western',
#   'Crime',
#   'Thriller',
#   'Action',
#   'Adventure',
#   'Sci-Fi',
#   'Comedy',
#   'Family'],
#  'Christoph Waltz': ['Drama', 'Western', 'Action', 'Adventure', 'Thriller'],
#  'Kerry Washington': ['Drama', 'Western'],
#  'Madhavan': ['Comedy', 'Drama'],
#  'Mona Singh': ['Comedy', 'Drama'],
#  'Sharman Joshi': ['Comedy', 'Drama'],
#  'Ben Burtt': ['Animation', 'Adventure', 'Family'],
#  'Elissa Knight': ['Animation', 'Adventure', 'Family'],
#  'Jeff Garlin': ['Animation', 'Adventure', 'Family'],
#  'Fred Willard': ['Animation', 'Adventure', 'Family'],
#  'Miyu Irino': ['Animation', 'Drama', 'Romance'],
#  'Saori Hayami': ['Animation', 'Drama', 'Romance'],
#  'Kensho Ono': ['Animation', 'Drama', 'Romance'],
#  'Ryan Gosling': ['Comedy',
#   'Drama',
#   'Music',
#   'Biography',
#   'Crime',
#   'Action',
#   'Romance',
#   'Thriller',
#   'Mystery'],
#  'Emma Stone': ['Comedy',
#   'Drama',
#   'Music',
#   'Adventure',
#   'Horror',
#   'Romance',
#   'Action',
#   'Sci-Fi',
#   'Crime'],
#  'Rosemarie DeWitt': ['Comedy', 'Drama', 'Music'],
#  'Prabhas': ['Action', 'Adventure', 'Drama'],
#  'Rana Daggubati': ['Action', 'Adventure', 'Drama'],
#  'Anushka Shetty': ['Action', 'Adventure', 'Drama'],
#  'Tamannaah Bhatia': ['Action', 'Adventure', 'Drama'],
#  'Brad Pitt': ['Adventure',
#   'Drama',
#   'War',
#   'Biography',
#   'History',
#   'Comedy',
#   'Fantasy',
#   'Romance',
#   'Action',
#   'Sport',
#   'Crime',
#   'Animation',
#   'Horror',
#   'Thriller'],
#  'Diane Kruger': ['Adventure',
#   'Drama',
#   'War',
#   'Fantasy',
#   'Romance',
#   'Biography',
#   'Crime',
#   'Action',
#   'Mystery',
#   'Thriller'],
#  'Eli Roth': ['Adventure', 'Drama', 'War'],
#  'Melanie Laurent': ['Adventure', 'Drama', 'War', 'Mystery', 'Thriller'],
#  'Mads Mikkelsen': ['Drama'],
#  'Thomas Bo Larsen': ['Drama'],
#  'Annika Wedderkopp': ['Drama'],
#  'Lasse Fogelstrom': ['Drama'],
#  'Alia Shawkat': ['Drama', 'Crime', 'Horror', 'Thriller'],
#  'Nancy Kwan': ['Drama'],
#  'Annabelle Attanasio': ['Drama'],
#  'Alfred Molina': ['Drama',
#   'Biography',
#   'Comedy',
#   'Action',
#   'Adventure',
#   'Fantasy'],
#  'Edward Asner': ['Animation', 'Adventure', 'Comedy'],
#  'Jordan Nagai': ['Animation', 'Adventure', 'Comedy'],
#  'John Ratzenberger': ['Animation', 'Adventure', 'Comedy'],
#  'Christopher Plummer': ['Animation',
#   'Adventure',
#   'Comedy',
#   'Crime',
#   'Drama',
#   'Mystery',
#   'Fantasy'],
#  'Tom Hanks': ['Animation',
#   'Adventure',
#   'Comedy',
#   'Biography',
#   'Drama',
#   'Thriller',
#   'History',
#   'Sci-Fi',
#   'Mystery',
#   'Action',
#   'Crime'],
#  'Tim Allen': ['Animation', 'Adventure', 'Comedy'],
#  'Joan Cusack': ['Animation', 'Adventure', 'Comedy'],
#  'Ned Beatty': ['Animation', 'Adventure', 'Comedy'],
#  'Andrew Garfield': ['Biography',
#   'Drama',
#   'History',
#   'Adventure',
#   'Action',
#   'Fantasy',
#   'Mystery',
#   'Sci-Fi'],
#  'Sam Worthington': ['Biography',
#   'Drama',
#   'History',
#   'Action',
#   'Adventure',
#   'Fantasy',
#   'Crime',
#   'Thriller'],
#  'Luke Bracey': ['Biography',
#   'Drama',
#   'History',
#   'Romance',
#   'Action',
#   'Crime',
#   'Sport'],
#  'Teresa Palmer': ['Biography',
#   'Drama',
#   'History',
#   'Comedy',
#   'Horror',
#   'Romance',
#   'Action',
#   'Adventure',
#   'Sci-Fi',
#   'Crime',
#   'Sport'],
#  'Jonah Hill': ['Biography',
#   'Comedy',
#   'Crime',
#   'Drama',
#   'Sport',
#   'Animation',
#   'Action',
#   'Fantasy',
#   'Adventure'],
#  'Margot Robbie': ['Biography',
#   'Comedy',
#   'Crime',
#   'Drama',
#   'Romance',
#   'War',
#   'Action',
#   'Adventure',
#   'Fantasy'],
#  'Brie Larson': ['Drama', 'Action', 'Comedy', 'Crime', 'Romance', 'Thriller'],
#  'Jacob Tremblay': ['Drama', 'Fantasy', 'Horror', 'Thriller'],
#  'Sean Bridgers': ['Drama'],
#  'Wendy Crewson': ['Drama'],
#  'Nick Nolte': ['Action', 'Drama', 'Sport'],
#  'Joel Edgerton': ['Action',
#   'Drama',
#   'Sport',
#   'History',
#   'Thriller',
#   'Romance',
#   'Biography',
#   'Mystery',
#   'Crime',
#   'Sci-Fi',
#   'Adventure'],
#  'Jennifer Morrison': ['Action', 'Drama', 'Sport'],
#  'Ivana Baquero': ['Drama', 'Fantasy', 'War'],
#  'Ariadna Gil': ['Drama', 'Fantasy', 'War'],
#  'Sergi Lopez': ['Drama', 'Fantasy', 'War'],
#  'Maribel Verdu': ['Drama', 'Fantasy', 'War'],
#  'Amy Poehler': ['Animation', 'Adventure', 'Comedy'],
#  'Bill Hader': ['Animation', 'Adventure', 'Comedy', 'Drama', 'Romance'],
#  'Lewis Black': ['Animation', 'Adventure', 'Comedy'],
#  'Mindy Kaling': ['Animation', 'Adventure', 'Comedy'],
#  'Clint Eastwood': ['Drama'],
#  'Bee Vang': ['Drama'],
#  'Christopher Carley': ['Drama'],
#  'Ahney Her': ['Drama'],
#  'Lubna Azabal': ['Drama', 'Mystery', 'War'],
#  'Melissa Desormeaux-Poulin': ['Drama', 'Mystery', 'War'],
#  'Maxim Gaudette': ['Drama', 'Mystery', 'War'],
#  'Mustafa Kamel': ['Drama', 'Mystery', 'War'],
#  'Ricardo Darin': ['Drama', 'Mystery', 'Romance'],
#  'Soledad Villamil': ['Drama', 'Mystery', 'Romance'],
#  'Pablo Rago': ['Drama', 'Mystery', 'Romance'],
#  'Carla Quevedo': ['Drama', 'Mystery', 'Romance'],
#  'Anushka Sharma': ['Comedy', 'Drama', 'Romance'],
#  'Sanjay Dutt': ['Comedy', 'Drama', 'Romance'],
#  'Boman Irani': ['Comedy', 'Drama', 'Romance'],
#  'Chris Pratt': ['Action',
#   'Adventure',
#   'Sci-Fi',
#   'Animation',
#   'Drama',
#   'History',
#   'Thriller',
#   'Romance',
#   'Western',
#   'Comedy'],
#  'Vin Diesel': ['Action',
#   'Adventure',
#   'Sci-Fi',
#   'Crime',
#   'Thriller',
#   'Fantasy'],
#  'Bradley Cooper': ['Action',
#   'Adventure',
#   'Sci-Fi',
#   'Comedy',
#   'Drama',
#   'Romance',
#   'Mystery',
#   'Thriller',
#   'Crime',
#   'Biography',
#   'Horror'],
#  'Zoe Saldana': ['Action',
#   'Adventure',
#   'Sci-Fi',
#   'Fantasy',
#   'Animation',
#   'Comedy',
#   'Crime',
#   'Drama',
#   'Thriller'],
#  'Dev Patel': ['Biography', 'Drama', 'Action', 'Crime', 'Adventure', 'Family'],
#  'Nicole Kidman': ['Biography',
#   'Drama',
#   'Adventure',
#   'Romance',
#   'Comedy',
#   'Crime',
#   'Mystery',
#   'Family',
#   'Fantasy'],
#  'Rooney Mara': ['Biography',
#   'Drama',
#   'Romance',
#   'Sci-Fi',
#   'Crime',
#   'Mystery',
#   'Adventure',
#   'Family',
#   'Fantasy'],
#  'Sunny Pawar': ['Biography', 'Drama'],
#  'Daisy Ridley': ['Action', 'Adventure', 'Fantasy'],
#  'John Boyega': ['Action', 'Adventure', 'Fantasy'],
#  'Oscar Isaac': ['Action',
#   'Adventure',
#   'Fantasy',
#   'Drama',
#   'Mystery',
#   'Sci-Fi',
#   'History'],
#  'Domhnall Gleeson': ['Action',
#   'Adventure',
#   'Fantasy',
#   'Drama',
#   'Thriller',
#   'Comedy',
#   'Mystery',
#   'Sci-Fi',
#   'Romance',
#   'Biography',
#   'Sport'],
#  'Charlize Theron': ['Action',
#   'Adventure',
#   'Sci-Fi',
#   'Animation',
#   'Family',
#   'Drama',
#   'Mystery',
#   'Crime',
#   'Thriller',
#   'Comedy',
#   'Romance',
#   'Western'],
#  'Nicholas Hoult': ['Action',
#   'Adventure',
#   'Sci-Fi',
#   'Comedy',
#   'Horror',
#   'Romance',
#   'Drama',
#   'Mystery',
#   'Thriller',
#   'Crime'],
#  'Zoe Kravitz': ['Action',
#   'Adventure',
#   'Sci-Fi',
#   'Crime',
#   'Drama',
#   'Thriller'],
#  'Ginnifer Goodwin': ['Animation', 'Adventure', 'Comedy'],
#  'Jason Bateman': ['Animation',
#   'Adventure',
#   'Comedy',
#   'Drama',
#   'Romance',
#   'Mystery',
#   'Thriller',
#   'Crime',
#   'Action'],
#  'Idris Elba': ['Animation',
#   'Adventure',
#   'Comedy',
#   'Drama',
#   'Family',
#   'Action',
#   'Crime',
#   'Thriller',
#   'Sci-Fi'],
#  'Jenny Slate': ['Animation', 'Adventure', 'Comedy'],
#  'Robert Downey Jr.': ['Action',
#   'Sci-Fi',
#   'Adventure',
#   'Crime',
#   'Drama',
#   'History',
#   'Comedy'],
#  'Chris Evans': ['Action',
#   'Sci-Fi',
#   'Adventure',
#   'Thriller',
#   'Drama',
#   'Comedy',
#   'Romance'],
#  'Jeremy Renner': ['Action',
#   'Sci-Fi',
#   'Drama',
#   'Mystery',
#   'Crime',
#   'Thriller',
#   'History',
#   'Adventure',
#   'Horror'],
#  'Ben Affleck': ['Crime',
#   'Drama',
#   'Mystery',
#   'Biography',
#   'History',
#   'Thriller',
#   'Action',
#   'Adventure',
#   'Sci-Fi'],
#  'Rosamund Pike': ['Crime',
#   'Drama',
#   'Mystery',
#   'Action',
#   'Comedy',
#   'Sci-Fi',
#   'Biography',
#   'Romance',
#   'Adventure',
#   'Fantasy'],
#  'Neil Patrick Harris': ['Crime', 'Drama', 'Mystery'],
#  'Tyler Perry': ['Crime', 'Drama', 'Mystery', 'Action', 'Adventure', 'Comedy'],
#  'Jake Gyllenhaal': ['Crime',
#   'Drama',
#   'Mystery',
#   'Thriller',
#   'History',
#   'Romance',
#   'Sci-Fi',
#   'Sport',
#   'Comedy',
#   'Action',
#   'Adventure',
#   'Fantasy'],
#  'Viola Davis': ['Crime',
#   'Drama',
#   'Mystery',
#   'Action',
#   'Adventure',
#   'Fantasy',
#   'Romance'],
#  'Melissa Leo': ['Crime',
#   'Drama',
#   'Mystery',
#   'Action',
#   'Biography',
#   'Thriller'],
#  'Octavia Spencer': ['Drama', 'Biography', 'History'],
#  'Bryce Dallas Howard': ['Drama',
#   'Comedy',
#   'Romance',
#   'Action',
#   'Adventure',
#   'Sci-Fi',
#   'Family',
#   'Fantasy',
#   'Thriller',
#   'Mystery'],
#  'Chiwetel Ejiofor': ['Biography',
#   'Drama',
#   'History',
#   'Sci-Fi',
#   'Thriller',
#   'Crime',
#   'Action',
#   'Adventure',
#   'Fantasy',
#   'Mystery',
#   'Romance'],
#  'Michael Kenneth Williams': ['Biography', 'Drama', 'History'],
#  'Michael Fassbender': ['Biography',
#   'Drama',
#   'History',
#   'Action',
#   'Adventure',
#   'Sci-Fi',
#   'Romance',
#   'Mystery',
#   'War',
#   'Crime',
#   'Thriller'],
#  'Daniel Radcliffe': ['Adventure',
#   'Drama',
#   'Fantasy',
#   'Family',
#   'Comedy',
#   'Romance',
#   'Crime',
#   'Thriller',
#   'Horror',
#   'Sci-Fi'],
#  'Emma Watson': ['Adventure',
#   'Drama',
#   'Fantasy',
#   'Romance',
#   'Family',
#   'Thriller',
#   'Action',
#   'Crime',
#   'Mystery'],
#  'Rupert Grint': ['Adventure', 'Drama', 'Fantasy', 'Family'],
#  'Michael Gambon': ['Adventure', 'Drama', 'Fantasy', 'Family'],
#  'Tommy Lee Jones': ['Crime',
#   'Drama',
#   'Thriller',
#   'Action',
#   'Adventure',
#   'Comedy'],
#  'Javier Bardem': ['Crime',
#   'Drama',
#   'Thriller',
#   'Action',
#   'Adventure',
#   'Romance'],
#  'Josh Brolin': ['Crime',
#   'Drama',
#   'Thriller',
#   'Biography',
#   'Action',
#   'Adventure',
#   'Western',
#   'Comedy',
#   'Horror',
#   'Mystery'],
#  'Woody Harrelson': ['Crime',
#   'Drama',
#   'Thriller',
#   'Adventure',
#   'Comedy',
#   'Horror',
#   'Romance',
#   'Mystery',
#   'Action',
#   'Sci-Fi'],
#  'Emily Mortimer': ['Mystery',
#   'Thriller',
#   'Action',
#   'Sci-Fi',
#   'Animation',
#   'Adventure',
#   'Comedy'],
#  'Mark Ruffalo': ['Mystery',
#   'Thriller',
#   'Crime',
#   'Drama',
#   'History',
#   'Action',
#   'Adventure',
#   'Sci-Fi',
#   'Music',
#   'Comedy'],
#  'Ben Kingsley': ['Mystery',
#   'Thriller',
#   'Crime',
#   'Drama',
#   'Adventure',
#   'Family',
#   'Action',
#   'Fantasy',
#   'Sci-Fi',
#   'Comedy'],
#  'Min-hee Kim': ['Drama', 'Mystery', 'Romance'],
#  'Jung-woo Ha': ['Drama', 'Mystery', 'Romance'],
#  'Jin-woong Jo': ['Drama', 'Mystery', 'Romance'],
#  'So-ri Moon': ['Drama', 'Mystery', 'Romance'],
#  'Chris Isaak': ['Drama', 'Horror', 'Mystery'],
#  'Kiefer Sutherland': ['Drama', 'Horror', 'Mystery', 'Action', 'Adventure'],
#  'C.H. Evans': ['Drama', 'Horror', 'Mystery'],
#  'Sandra Kinder': ['Drama', 'Horror', 'Mystery'],
#  'Michael Keaton': ['Crime',
#   'Drama',
#   'History',
#   'Comedy',
#   'Romance',
#   'Biography',
#   'Animation',
#   'Action',
#   'Adventure',
#   'Sci-Fi'],
#  'Rachel McAdams': ['Crime',
#   'Drama',
#   'History',
#   'Comedy',
#   'Fantasy',
#   'Romance',
#   'Action',
#   'Adventure',
#   'Sport'],
#  'Liev Schreiber': ['Crime',
#   'Drama',
#   'History',
#   'Biography',
#   'Sport',
#   'Action',
#   'Adventure',
#   'Sci-Fi',
#   'Mystery',
#   'Comedy',
#   'Romance'],
#  'Emile Hirsch': ['Adventure',
#   'Biography',
#   'Drama',
#   'Action',
#   'Horror',
#   'Mystery',
#   'Thriller',
#   'Crime'],
#  'Vince Vaughn': ['Adventure', 'Biography', 'Drama', 'Comedy', 'Romance'],
#  'Catherine Keener': ['Adventure', 'Biography', 'Drama', 'Thriller', 'Crime'],
#  'Marcia Gay Harden': ['Adventure', 'Biography', 'Drama', 'Horror'],
#  'Benedict Cumberbatch': ['Biography',
#   'Drama',
#   'Thriller',
#   'Action',
#   'Adventure',
#   'Sci-Fi',
#   'Fantasy',
#   'Crime'],
#  'Keira Knightley': ['Biography',
#   'Drama',
#   'Thriller',
#   'Mystery',
#   'Romance',
#   'Music',
#   'Action',
#   'Adventure',
#   'Fantasy'],
#  'Matthew Goode': ['Biography',
#   'Drama',
#   'Thriller',
#   'Action',
#   'Mystery',
#   'Sci-Fi'],
#  'Allen Leech': ['Biography', 'Drama', 'Thriller'],
#  'Ralph Fiennes': ['Adventure',
#   'Comedy',
#   'Drama',
#   'Animation',
#   'Family',
#   'Action',
#   'Thriller',
#   'Mystery',
#   'Fantasy'],
#  'F. Murray Abraham': ['Adventure', 'Comedy', 'Drama'],
#  'Mathieu Amalric': ['Adventure', 'Comedy', 'Drama', 'Action', 'Thriller'],
#  'Adrien Brody': ['Adventure', 'Comedy', 'Drama', 'Action', 'Sci-Fi'],
#  'Daniel Day-Lewis': ['Drama', 'History', 'Biography'],
#  'Paul Dano': ['Drama', 'History', 'Action', 'Crime', 'Adventure', 'Comedy'],
#  'Ciaran Hinds': ['Drama',
#   'History',
#   'Comedy',
#   'Crime',
#   'Biography',
#   'Sport',
#   'Mystery'],
#  'Martin Stringer': ['Drama', 'History'],
#  'Daniel Bruhl': ['Action',
#   'Biography',
#   'Drama',
#   'History',
#   'Romance',
#   'Thriller',
#   'Comedy'],
#  'Chris Hemsworth': ['Action',
#   'Biography',
#   'Drama',
#   'Adventure',
#   'Sci-Fi',
#   'Fantasy',
#   'Horror',
#   'Crime',
#   'Mystery',
#   'Thriller'],
#  'Olivia Wilde': ['Action',
#   'Biography',
#   'Drama',
#   'Adventure',
#   'Sci-Fi',
#   'Thriller'],
#  'Alexandra Maria Lara': ['Action', 'Biography', 'Drama'],
#  'Edgar Ramirez': ['Action',
#   'Mystery',
#   'Thriller',
#   'Adventure',
#   'Drama',
#   'Biography',
#   'Crime',
#   'Sport'],
#  'Joan Allen': ['Action', 'Mystery', 'Thriller', 'Drama', 'Family', 'Sci-Fi'],
#  'Julia Stiles': ['Action', 'Mystery', 'Thriller'],
#  'Anne Dorval': ['Drama'],
#  'Antoine-Olivier Pilon': ['Drama'],
#  'Suzanne Clement': ['Drama'],
#  'Patrick Huard': ['Drama'],
#  'Dario Grandinetti': ['Comedy', 'Drama', 'Thriller'],
#  'Maria Marull': ['Comedy', 'Drama', 'Thriller'],
#  'Monica Villa': ['Comedy', 'Drama', 'Thriller'],
#  'Rita Cortese': ['Comedy', 'Drama', 'Thriller'],
#  'Richard Gere': ['Drama', 'Family', 'Thriller', 'Comedy', 'Romance'],
#  'Cary-Hiroyuki Tagawa': ['Drama', 'Family'],
#  'Sarah Roemer': ['Drama', 'Family', 'Mystery', 'Thriller'],
#  'Jay Baruchel': ['Animation',
#   'Action',
#   'Adventure',
#   'Comedy',
#   'Fantasy',
#   'Romance'],
#  'Gerard Butler': ['Animation',
#   'Action',
#   'Adventure',
#   'Fantasy',
#   'War',
#   'Crime',
#   'Drama',
#   'Thriller',
#   'Romance',
#   'Comedy'],
#  'Christopher Mintz-Plasse': ['Animation',
#   'Action',
#   'Adventure',
#   'Comedy',
#   'Crime'],
#  'Craig Ferguson': ['Animation', 'Action', 'Adventure'],
#  'Amy Adams': ['Drama',
#   'Mystery',
#   'Sci-Fi',
#   'Romance',
#   'Action',
#   'Biography',
#   'Thriller',
#   'Crime',
#   'Adventure',
#   'Fantasy',
#   'Animation',
#   'Comedy',
#   'Family'],
#  'Forest Whitaker': ['Drama',
#   'Mystery',
#   'Sci-Fi',
#   'Sport',
#   'Biography',
#   'Action',
#   'Thriller'],
#  'Michael Stuhlbarg': ['Drama', 'Mystery', 'Sci-Fi', 'Thriller'],
#  'Ryan Reynolds': ['Action',
#   'Adventure',
#   'Comedy',
#   'Biography',
#   'Drama',
#   'History',
#   'Sci-Fi',
#   'Romance',
#   'Mystery',
#   'Crime'],
#  'Morena Baccarin': ['Action', 'Adventure', 'Comedy'],
#  'T.J. Miller': ['Action',
#   'Adventure',
#   'Comedy',
#   'Animation',
#   'Horror',
#   'Sci-Fi',
#   'Romance'],
#  'Ed Skrein': ['Action', 'Adventure', 'Comedy'],
#  'Kristen Wiig': ['Adventure',
#   'Drama',
#   'Sci-Fi',
#   'Animation',
#   'Comedy',
#   'Romance',
#   'Action',
#   'Crime',
#   'Fantasy'],
#  'Kate Mara': ['Adventure',
#   'Drama',
#   'Sci-Fi',
#   'Biography',
#   'Horror',
#   'Thriller',
#   'Action'],
#  'Will Poulter': ['Adventure',
#   'Drama',
#   'Thriller',
#   'Action',
#   'Mystery',
#   'Sci-Fi'],
#  'Chris Pine': ['Action',
#   'Adventure',
#   'Sci-Fi',
#   'Crime',
#   'Drama',
#   'Thriller',
#   'History',
#   'Comedy',
#   'Romance'],
#  'Zachary Quinto': ['Action',
#   'Adventure',
#   'Sci-Fi',
#   'Biography',
#   'Drama',
#   'Thriller'],
#  'Simon Pegg': ['Action',
#   'Adventure',
#   'Sci-Fi',
#   'Comedy',
#   'Mystery',
#   'Thriller'],
#  'Leonard Nimoy': ['Action', 'Adventure', 'Sci-Fi'],
#  'Patrick Stewart': ['Action',
#   'Adventure',
#   'Sci-Fi',
#   'Crime',
#   'Horror',
#   'Thriller',
#   'Fantasy'],
#  'Ian McKellen': ['Action',
#   'Adventure',
#   'Sci-Fi',
#   'Fantasy',
#   'Family',
#   'Mystery',
#   'Thriller'],
#  'James McAvoy': ['Action',
#   'Adventure',
#   'Sci-Fi',
#   'Drama',
#   'Mystery',
#   'Romance',
#   'Horror',
#   'Thriller',
#   'Comedy',
#   'Crime',
#   'Fantasy'],
#  'Daniel Craig': ['Action',
#   'Adventure',
#   'Thriller',
#   'Crime',
#   'Drama',
#   'Mystery',
#   'Family',
#   'Fantasy'],
#  'Eva Green': ['Action',
#   'Adventure',
#   'Thriller',
#   'Drama',
#   'Family',
#   'Fantasy',
#   'Comedy',
#   'Horror'],
#  'Judi Dench': ['Action', 'Adventure', 'Thriller', 'Drama', 'Family'],
#  'Jeffrey Wright': ['Action',
#   'Adventure',
#   'Thriller',
#   'Mystery',
#   'Romance',
#   'Sci-Fi',
#   'Drama',
#   'Fantasy'],
#  'Joaquin Phoenix': ['Drama', 'Romance', 'Sci-Fi', 'Comedy', 'Crime'],
#  'Taraneh Alidoosti': ['Drama', 'Thriller'],
#  'Shahab Hosseini': ['Drama', 'Thriller'],
#  'Babak Karimi': ['Drama', 'Thriller'],
#  'Farid Sajjadi Hosseini': ['Drama', 'Thriller'],
#  'Logan Lerman': ['Drama',
#   'Romance',
#   'Action',
#   'War',
#   'Adventure',
#   'Family',
#   'Fantasy'],
#  'Ezra Miller': ['Drama',
#   'Romance',
#   'Mystery',
#   'Thriller',
#   'Biography',
#   'History'],
#  'Paul Rudd': ['Drama', 'Romance', 'Action', 'Adventure', 'Comedy'],
#  'Natalie Portman': ['Drama',
#   'Thriller',
#   'Action',
#   'Adventure',
#   'Fantasy',
#   'Biography',
#   'History',
#   'Comedy',
#   'Romance'],
#  'Mila Kunis': ['Drama',
#   'Thriller',
#   'Comedy',
#   'Romance',
#   'Fantasy',
#   'Action',
#   'Adventure',
#   'Family',
#   'Sci-Fi'],
#  'Vincent Cassel': ['Drama',
#   'Thriller',
#   'Crime',
#   'Mystery',
#   'Action',
#   'Fantasy',
#   'Horror'],
#  'Winona Ryder': ['Drama', 'Thriller'],
#  'Ferdia Walsh-Peelo': ['Comedy', 'Drama', 'Music'],
#  'Aidan Gillen': ['Comedy', 'Drama', 'Music'],
#  'Maria Doyle Kennedy': ['Comedy', 'Drama', 'Music'],
#  'Jack Reynor': ['Comedy', 'Drama', 'Music', 'Action', 'Adventure', 'Sci-Fi'],
#  'Jennifer Garner': ['Biography', 'Drama', 'Comedy', 'Family', 'Fantasy'],
#  'Jared Leto': ['Biography',
#   'Drama',
#   'Fantasy',
#   'Romance',
#   'Action',
#   'Adventure'],
#  'Steve Zahn': ['Biography', 'Drama', 'Adventure', 'Comedy', 'Family'],
#  'Freida Pinto': ['Drama', 'Action', 'Sci-Fi'],
#  'Saurabh Shukla': ['Drama'],
#  'Anil Kapoor': ['Drama'],
#  'Sharlto Copley': ['Action',
#   'Sci-Fi',
#   'Thriller',
#   'Comedy',
#   'Crime',
#   'Adventure',
#   'Family',
#   'Drama',
#   'Romance',
#   'Mystery'],
#  'David James': ['Action', 'Sci-Fi', 'Thriller'],
#  'Jason Cope': ['Action', 'Sci-Fi', 'Thriller'],
#  'Nathalie Boltt': ['Action', 'Sci-Fi', 'Thriller'],
#  'Brad Garrett': ['Animation', 'Comedy', 'Family'],
#  'Lou Romano': ['Animation', 'Comedy', 'Family'],
#  'Patton Oswalt': ['Animation', 'Comedy', 'Family'],
#  'Ian Holm': ['Animation', 'Comedy', 'Family'],
#  'Will Smith': ['Biography',
#   'Drama',
#   'Romance',
#   'Horror',
#   'Sci-Fi',
#   'Sport',
#   'Action',
#   'Adventure',
#   'Comedy',
#   'Crime',
#   'Fantasy'],
#  'Thandie Newton': ['Biography',
#   'Drama',
#   'Action',
#   'Crime',
#   'Thriller',
#   'Romance',
#   'Adventure',
#   'Sci-Fi'],
#  'Jaden Smith': ['Biography',
#   'Drama',
#   'Action',
#   'Family',
#   'Adventure',
#   'Sci-Fi'],
#  'Brian Howe': ['Biography', 'Drama'],
#  'Djimon Hounsou': ['Adventure', 'Drama', 'Thriller', 'Action', 'Sport'],
#  'Jennifer Connelly': ['Adventure',
#   'Drama',
#   'Thriller',
#   'Comedy',
#   'Romance',
#   'Crime',
#   'Action'],
#  'Kagiso Kuypers': ['Adventure', 'Drama', 'Thriller'],
#  'Colin Firth': ['Biography',
#   'Drama',
#   'Action',
#   'Adventure',
#   'Comedy',
#   'Mystery',
#   'Thriller',
#   'Crime'],
#  'Geoffrey Rush': ['Biography',
#   'Drama',
#   'Crime',
#   'Mystery',
#   'Action',
#   'Adventure',
#   'Fantasy'],
#  'Helena Bonham Carter': ['Biography',
#   'Drama',
#   'Horror',
#   'Musical',
#   'Family',
#   'Fantasy',
#   'Adventure',
#   'Comedy'],
#  'Derek Jacobi': ['Biography', 'Drama'],
#  'Felicity Jones': ['Action',
#   'Adventure',
#   'Sci-Fi',
#   'Biography',
#   'Drama',
#   'Romance',
#   'Fantasy',
#   'Crime',
#   'Thriller'],
#  'Diego Luna': ['Action',
#   'Adventure',
#   'Sci-Fi',
#   'Animation',
#   'Comedy',
#   'Crime',
#   'Drama',
#   'Romance'],
#  'Alan Tudyk': ['Action', 'Adventure', 'Sci-Fi'],
#  'Donnie Yen': ['Action', 'Adventure', 'Sci-Fi'],
#  'Casey Affleck': ['Drama',
#   'Crime',
#   'Mystery',
#   'Biography',
#   'Action',
#   'History',
#   'Thriller'],
#  'Michelle Williams': ['Drama',
#   'Romance',
#   'War',
#   'Adventure',
#   'Family',
#   'Fantasy'],
#  'Kyle Chandler': ['Drama',
#   'Romance',
#   'Mystery',
#   'Sci-Fi',
#   'Thriller',
#   'Comedy'],
#  'Lucas Hedges': ['Drama'],
#  'Sebastian Stan': ['Action', 'Adventure', 'Sci-Fi'],
#  'Viggo Mortensen': ['Comedy', 'Drama', 'Crime', 'Mystery', 'Adventure'],
#  'George MacKay': ['Comedy', 'Drama'],
#  'Samantha Isler': ['Comedy', 'Drama'],
#  'Annalise Basso': ['Comedy', 'Drama', 'Horror', 'Thriller'],
#  'Mario Casas': ['Crime', 'Mystery', 'Thriller'],
#  'Ana Wagener': ['Crime', 'Mystery', 'Thriller'],
#  'Jose Coronado': ['Crime', 'Mystery', 'Thriller'],
#  'Barbara Lennie': ['Crime', 'Mystery', 'Thriller'],
#  'Nick Frost': ['Action', 'Comedy', 'Mystery', 'Adventure', 'Sci-Fi'],
#  'Martin Freeman': ['Action',
#   'Comedy',
#   'Mystery',
#   'Adventure',
#   'Fantasy',
#   'Sci-Fi',
#   'Biography',
#   'Drama'],
#  'Bill Nighy': ['Action',
#   'Comedy',
#   'Mystery',
#   'Drama',
#   'Fantasy',
#   'Adventure',
#   'Family',
#   'Romance'],
#  'Rene Russo': ['Crime', 'Drama', 'Thriller', 'Comedy'],
#  'Bill Paxton': ['Crime',
#   'Drama',
#   'Thriller',
#   'Action',
#   'Adventure',
#   'Sci-Fi'],
#  'Riz Ahmed': ['Crime', 'Drama', 'Thriller'],
#  'Art Parkinson': ['Animation',
#   'Adventure',
#   'Family',
#   'Action',
#   'Drama',
#   'Fantasy'],
#  'Tom Cruise': ['Action',
#   'Adventure',
#   'Sci-Fi',
#   'Thriller',
#   'Mystery',
#   'Crime',
#   'Comedy',
#   'Drama',
#   'Musical'],
#  'Emily Blunt': ['Action',
#   'Adventure',
#   'Sci-Fi',
#   'Crime',
#   'Drama',
#   'Romance',
#   'Thriller',
#   'Comedy',
#   'Mystery'],
#  'Brendan Gleeson': ['Action',
#   'Adventure',
#   'Sci-Fi',
#   'Comedy',
#   'Crime',
#   'Drama',
#   'Family',
#   'Fantasy',
#   'Biography'],
#  'Gwyneth Paltrow': ['Action', 'Adventure', 'Sci-Fi', 'Drama', 'Thriller'],
#  'Terrence Howard': ['Action', 'Adventure', 'Sci-Fi', 'Drama', 'Music'],
#  'Jeff Bridges': ['Action',
#   'Adventure',
#   'Sci-Fi',
#   'Crime',
#   'Drama',
#   'Thriller',
#   'Western',
#   'Romance',
#   'Fantasy'],
#  'Julianne Moore': ['Drama',
#   'Sci-Fi',
#   'Thriller',
#   'Comedy',
#   'Romance',
#   'Horror',
#   'Action',
#   'Adventure',
#   'Fantasy'],
#  'Clive Owen': ['Drama', 'Sci-Fi', 'Thriller', 'Crime', 'Mystery'],
#  "O'Shea Jackson Jr.": ['Biography', 'Drama', 'History'],
#  'Corey Hawkins': ['Biography', 'Drama', 'History'],
#  'Jason Mitchell': ['Biography', 'Drama', 'History'],
#  'Neil Brown Jr.': ['Biography', 'Drama', 'History'],
#  'Richard Armitage': ['Adventure', 'Fantasy'],
#  'Andy Serkis': ['Adventure', 'Fantasy', 'Action', 'Drama', 'Sci-Fi'],
#  'Sam Neill': ['Adventure', 'Comedy', 'Drama'],
#  'Julian Dennison': ['Adventure', 'Comedy', 'Drama'],
#  'Rima Te Wiata': ['Adventure', 'Comedy', 'Drama'],
#  'Rachel House': ['Adventure', 'Comedy', 'Drama', 'Animation'],
#  'Sarah Polley': ['Drama', 'Fantasy', 'Romance'],
#  'Linh Dan Pham': ['Drama', 'Fantasy', 'Romance'],
#  'Ken Stott': ['Adventure', 'Fantasy'],
#  'Dave Johns': ['Drama'],
#  'Hayley Squires': ['Drama'],
#  'Sharon Percy': ['Drama'],
#  'Briana Shann': ['Drama'],
#  'Sam Rockwell': ['Drama',
#   'Mystery',
#   'Sci-Fi',
#   'Comedy',
#   'Crime',
#   'Action',
#   'Romance'],
#  'Kevin Spacey': ['Drama',
#   'Mystery',
#   'Sci-Fi',
#   'Crime',
#   'Thriller',
#   'Action',
#   'Adventure',
#   'Comedy',
#   'Family',
#   'Fantasy'],
#  'Dominique McElligott': ['Drama', 'Mystery', 'Sci-Fi'],
#  'Rosie Shaw': ['Drama', 'Mystery', 'Sci-Fi'],
#  'Ellar Coltrane': ['Drama'],
#  'Patricia Arquette': ['Drama'],
#  'Ethan Hawke': ['Drama',
#   'Biography',
#   'Romance',
#   'Mystery',
#   'Sci-Fi',
#   'Action',
#   'Adventure',
#   'Western',
#   'Horror',
#   'Crime',
#   'Thriller'],
#  'Elijah Smith': ['Drama'],
#  'Suraj Sharma': ['Adventure', 'Drama', 'Fantasy'],
#  'Irrfan Khan': ['Adventure', 'Drama', 'Fantasy', 'Action', 'Crime'],
#  'Adil Hussain': ['Adventure', 'Drama', 'Fantasy'],
#  'Tabu': ['Adventure', 'Drama', 'Fantasy'],
#  'Colin Farrell': ['Comedy',
#   'Crime',
#   'Drama',
#   'Biography',
#   'Romance',
#   'Mystery',
#   'Action',
#   'Adventure'],
#  'Elizabeth Berrington': ['Comedy', 'Crime', 'Drama'],
#  'Lee Pace': ['Adventure', 'Comedy', 'Drama'],
#  'Catinca Untaru': ['Adventure', 'Comedy', 'Drama'],
#  'Justine Waddell': ['Adventure', 'Comedy', 'Drama'],
#  'Kim Uylenbroek': ['Adventure', 'Comedy', 'Drama'],
#  'Cate Blanchett': ['Animation',
#   'Action',
#   'Adventure',
#   'Drama',
#   'Fantasy',
#   'Romance',
#   'Family',
#   'Thriller'],
#  'Taraji P. Henson': ['Biography', 'Drama', 'History', 'Action', 'Family'],
#  'Janelle Monae': ['Biography', 'Drama', 'History'],
#  'Kevin Costner': ['Biography',
#   'Drama',
#   'History',
#   'Crime',
#   'Thriller',
#   'Action'],
#  'Sigourney Weaver': ['Action',
#   'Adventure',
#   'Fantasy',
#   'Drama',
#   'Crime',
#   'Thriller'],
#  'Michelle Rodriguez': ['Action',
#   'Adventure',
#   'Fantasy',
#   'Crime',
#   'Thriller',
#   'Horror',
#   'Sci-Fi'],
#  'Samuel L. Jackson': ['Crime',
#   'Drama',
#   'Mystery',
#   'Action',
#   'Adventure',
#   'Sci-Fi',
#   'Comedy',
#   'Fantasy',
#   'Horror',
#   'Family'],
#  'Kurt Russell': ['Crime',
#   'Drama',
#   'Mystery',
#   'Action',
#   'Horror',
#   'Thriller',
#   'Adventure'],
#  'Jennifer Jason Leigh': ['Crime', 'Drama', 'Mystery', 'Comedy', 'Romance'],
#  'Walton Goggins': ['Crime', 'Drama', 'Mystery'],
#  'Steve Carell': ['Biography',
#   'Comedy',
#   'Drama',
#   'Animation',
#   'Adventure',
#   'Romance',
#   'Family'],
#  'Carey Mulligan': ['Crime', 'Drama', 'Romance'],
#  'Bryan Cranston': ['Crime',
#   'Drama',
#   'Biography',
#   'History',
#   'Animation',
#   'Action',
#   'Adventure',
#   'Sci-Fi',
#   'Mystery'],
#  'Albert Brooks': ['Crime',
#   'Drama',
#   'Animation',
#   'Adventure',
#   'Comedy',
#   'Biography',
#   'Sport'],
#  'Jennifer Lawrence': ['Action',
#   'Adventure',
#   'Sci-Fi',
#   'Comedy',
#   'Drama',
#   'Romance',
#   'Mystery',
#   'Crime',
#   'Thriller'],
#  'Kevin Bacon': ['Action', 'Adventure', 'Sci-Fi', 'Comedy', 'Drama'],
#  'Robert Redford': ['Action', 'Adventure', 'Sci-Fi', 'Family', 'Fantasy'],
#  'Stellan Skarsgard': ['Crime',
#   'Drama',
#   'Mystery',
#   'Action',
#   'Adventure',
#   'Fantasy',
#   'Comedy',
#   'Family',
#   'Musical'],
#  'Gerardo Taracena': ['Action', 'Adventure', 'Drama'],
#  'Raoul Max Trujillo': ['Action', 'Adventure', 'Drama'],
#  'Dalia Hernandez': ['Action', 'Adventure', 'Drama'],
#  'Rudy Youngblood': ['Action', 'Adventure', 'Drama'],
#  'Zach Galifianakis': ['Comedy', 'Drama', 'Romance', 'Action', 'Crime'],
#  'Justin Bartha': ['Comedy', 'Drama'],
#  'Ed Helms': ['Comedy', 'Crime', 'Adventure'],
#  'Edward Norton': ['Comedy',
#   'Drama',
#   'Romance',
#   'Mystery',
#   'Action',
#   'Adventure',
#   'Sci-Fi'],
#  'Andrea Riseborough': ['Comedy',
#   'Drama',
#   'Romance',
#   'Action',
#   'Adventure',
#   'Mystery'],
#  'Naomie Harris': ['Action', 'Adventure', 'Thriller'],
#  'Lea Seydoux': ['Drama', 'Romance', 'Action', 'Adventure', 'Thriller'],
#  'Adele Exarchopoulos': ['Drama', 'Romance'],
#  'Salim Kechiouche': ['Drama', 'Romance'],
#  'Aurelien Recoing': ['Drama', 'Romance'],
#  'Robert De Niro': ['Comedy',
#   'Drama',
#   'Romance',
#   'Mystery',
#   'Sci-Fi',
#   'Thriller',
#   'Action',
#   'Biography',
#   'Crime'],
#  'Jacki Weaver': ['Comedy', 'Drama', 'Romance'],
#  'Shailene Woodley': ['Drama',
#   'Romance',
#   'Biography',
#   'Thriller',
#   'Comedy',
#   'Adventure',
#   'Mystery',
#   'Sci-Fi',
#   'Action'],
#  'Ansel Elgort': ['Drama', 'Romance', 'Adventure', 'Sci-Fi', 'Thriller'],
#  'Nat Wolff': ['Drama', 'Romance', 'Mystery'],
#  'Laura Dern': ['Drama',
#   'Romance',
#   'Adventure',
#   'Biography',
#   'Mystery',
#   'Thriller'],
#  'Lydia Wilson': ['Comedy', 'Drama', 'Fantasy'],
#  'Will Ferrell': ['Animation',
#   'Action',
#   'Adventure',
#   'Comedy',
#   'Crime',
#   'Sport',
#   'Family'],
#  'Elizabeth Banks': ['Animation',
#   'Action',
#   'Adventure',
#   'Comedy',
#   'Romance',
#   'Crime',
#   'Thriller',
#   'Horror',
#   'Sci-Fi'],
#  'Will Arnett': ['Animation', 'Action', 'Adventure', 'Comedy'],
#  'Mandy Moore': ['Animation', 'Adventure', 'Comedy'],
#  'Zachary Levi': ['Animation', 'Adventure', 'Comedy'],
#  'Donna Murphy': ['Animation', 'Adventure', 'Comedy'],
#  'Ron Perlman': ['Animation',
#   'Adventure',
#   'Comedy',
#   'Action',
#   'Fantasy',
#   'Biography',
#   'Drama',
#   'Sport'],
#  'Liam Neeson': ['Action',
#   'Thriller',
#   'Adventure',
#   'Drama',
#   'History',
#   'Mystery',
#   'Comedy',
#   'Crime',
#   'Romance',
#   'Western',
#   'Sci-Fi',
#   'Fantasy'],
#  'Maggie Grace': ['Action', 'Thriller', 'Drama', 'Romance', 'Crime'],
#  'Famke Janssen': ['Action', 'Thriller', 'Adventure', 'Fantasy'],
#  'Leland Orser': ['Action', 'Thriller'],
#  'Brenda Blethyn': ['Drama', 'Mystery', 'Romance'],
#  'Saoirse Ronan': ['Drama',
#   'Mystery',
#   'Romance',
#   'Action',
#   'Thriller',
#   'Fantasy',
#   'Adventure'],
#  'Tilda Swinton': ['Drama',
#   'Fantasy',
#   'Romance',
#   'Mystery',
#   'Thriller',
#   'Action',
#   'Sci-Fi'],
#  'Julia Ormond': ['Drama', 'Fantasy', 'Romance'],
#  'Ryan Potter': ['Animation', 'Action', 'Adventure'],
#  'Scott Adsit': ['Animation', 'Action', 'Adventure'],
#  'Jamie Chung': ['Animation', 'Action', 'Adventure'],
#  'Denzel Washington': ['Biography',
#   'Crime',
#   'Drama',
#   'Mystery',
#   'Thriller',
#   'Action',
#   'Sci-Fi',
#   'Adventure',
#   'Western'],
#  'Russell Crowe': ['Biography',
#   'Crime',
#   'Drama',
#   'Musical',
#   'Romance',
#   'Action',
#   'Comedy',
#   'Adventure'],
#  'Jared Gilman': ['Adventure', 'Comedy', 'Drama'],
#  'Kara Hayward': ['Adventure', 'Comedy', 'Drama'],
#  'Bruce Willis': ['Adventure',
#   'Comedy',
#   'Drama',
#   'Action',
#   'Crime',
#   'Thriller'],
#  'Bill Murray': ['Adventure', 'Comedy', 'Drama', 'Animation', 'Family'],
#  'Sandra Bullock': ['Drama',
#   'Sci-Fi',
#   'Thriller',
#   'Biography',
#   'Sport',
#   'Comedy',
#   'Romance',
#   'Action',
#   'Crime',
#   'Animation',
#   'Adventure'],
#  'George Clooney': ['Drama',
#   'Sci-Fi',
#   'Thriller',
#   'Animation',
#   'Adventure',
#   'Comedy',
#   'Romance',
#   'Crime',
#   'Action',
#   'Family',
#   'Mystery'],
#  'Ed Harris': ['Drama', 'Sci-Fi', 'Thriller', 'Crime', 'Mystery', 'Action'],
#  'Orto Ignatiussen': ['Drama', 'Sci-Fi', 'Thriller'],
#  'Asa Butterfield': ['Drama',
#   'War',
#   'Adventure',
#   'Family',
#   'Action',
#   'Sci-Fi'],
#  'David Thewlis': ['Drama', 'War', 'Crime', 'Mystery'],
#  'Rupert Friend': ['Drama', 'War'],
#  "Zac Mattoon O'Brien": ['Drama', 'War'],
#  'John C. Reilly': ['Animation',
#   'Adventure',
#   'Comedy',
#   'Drama',
#   'Mystery',
#   'Thriller',
#   'Action',
#   'Sport',
#   'Fantasy',
#   'Horror'],
#  'Jack McBrayer': ['Animation', 'Adventure', 'Comedy'],
#  'Jane Lynch': ['Animation', 'Adventure', 'Comedy'],
#  'Sarah Silverman': ['Animation', 'Adventure', 'Comedy', 'Music'],
#  'Toni Collette': ['Comedy', 'Drama', 'Crime', 'Thriller'],
#  'Greg Kinnear': ['Comedy', 'Drama'],
#  'Abigail Breslin': ['Comedy',
#   'Drama',
#   'Adventure',
#   'Horror',
#   'Action',
#   'Sci-Fi',
#   'Thriller'],
#  'Michael Nyqvist': ['Drama',
#   'Mystery',
#   'Thriller',
#   'Action',
#   'Crime',
#   'Romance'],
#  'Noomi Rapace': ['Drama',
#   'Mystery',
#   'Thriller',
#   'Crime',
#   'Adventure',
#   'Sci-Fi',
#   'Horror'],
#  'Ewa Froling': ['Drama', 'Mystery', 'Thriller'],
#  'Lena Endre': ['Drama', 'Mystery', 'Thriller'],
#  'Alia Bhatt': ['Drama', 'Romance'],
#  'Shah Rukh Khan': ['Drama', 'Romance'],
#  'Kunal Kapoor': ['Drama', 'Romance'],
#  'Priyanka Moodley': ['Drama', 'Romance'],
#  'Barkhad Abdi': ['Biography', 'Drama', 'Thriller', 'War'],
#  'Barkhad Abdirahman': ['Biography', 'Drama', 'Thriller'],
#  'Gaspard Schlatter': ['Animation', 'Comedy', 'Drama'],
#  'Sixtine Murat': ['Animation', 'Comedy', 'Drama'],
#  'Paulin Jaccoud': ['Animation', 'Comedy', 'Drama'],
#  'Michel Vuillermoz': ['Animation', 'Comedy', 'Drama'],
#  'Meryl Streep': ['Animation',
#   'Adventure',
#   'Comedy',
#   'Biography',
#   'Drama',
#   'Romance',
#   'Sci-Fi',
#   'Family',
#   'Musical'],
#  'Jason Schwartzman': ['Animation',
#   'Adventure',
#   'Comedy',
#   'Biography',
#   'Drama',
#   'History'],
#  'Sally Hawkins': ['Biography', 'Drama', 'Romance'],
#  'Kari Matchett': ['Biography', 'Drama', 'Romance'],
#  'Zachary Bennett': ['Biography', 'Drama', 'Romance'],
#  'Jim Sturgess': ['Crime',
#   'Drama',
#   'Mystery',
#   'Fantasy',
#   'Musical',
#   'Romance',
#   'Thriller',
#   'Biography',
#   'History'],
#  'Sylvia Hoeks': ['Crime', 'Drama', 'Mystery'],
#  'Donald Sutherland': ['Crime',
#   'Drama',
#   'Mystery',
#   'Action',
#   'Adventure',
#   'Comedy'],
#  'Angelina Jolie': ['Biography',
#   'Drama',
#   'Mystery',
#   'Animation',
#   'Action',
#   'Adventure',
#   'Family',
#   'Crime',
#   'Fantasy'],
#  'Colm Feore': ['Biography', 'Drama', 'Mystery'],
#  'Amy Ryan': ['Biography',
#   'Drama',
#   'Mystery',
#   'History',
#   'Thriller',
#   'Crime',
#   'Action',
#   'Comedy'],
#  'Gattlin Griffith': ['Biography', 'Drama', 'Mystery'],
#  'Thomas Mann': ['Comedy', 'Drama'],
#  'RJ Cyler': ['Comedy', 'Drama'],
#  'Olivia Cooke': ['Comedy', 'Drama'],
#  'Nick Offerman': ['Comedy',
#   'Drama',
#   'Biography',
#   'History',
#   'Adventure',
#   'Action',
#   'Crime'],
#  'Josh Hartnett': ['Crime', 'Drama', 'Mystery'],
#  'Morgan Freeman': ['Crime',
#   'Drama',
#   'Mystery',
#   'Action',
#   'Comedy',
#   'Adventure',
#   'Fantasy',
#   'Thriller',
#   'Sci-Fi',
#   'Romance'],
#  'Lucy Liu': ['Crime', 'Drama', 'Mystery'],
#  "Auli'i Cravalho": ['Animation', 'Adventure', 'Comedy'],
#  'Dwayne Johnson': ['Animation',
#   'Adventure',
#   'Comedy',
#   'Action',
#   'Crime',
#   'Thriller',
#   'Drama',
#   'Sci-Fi'],
#  'Temuera Morrison': ['Animation', 'Adventure', 'Comedy'],
#  'Taron Egerton': ['Action',
#   'Adventure',
#   'Comedy',
#   'Biography',
#   'Drama',
#   'Crime'],
#  'Ben Foster': ['Crime',
#   'Drama',
#   'Thriller',
#   'Action',
#   'Biography',
#   'Adventure',
#   'Fantasy',
#   'Horror',
#   'Mystery',
#   'History'],
#  'Gil Birmingham': ['Crime', 'Drama', 'Thriller', 'Adventure', 'Fantasy'],
#  'Alicia Vikander': ['Drama',
#   'Mystery',
#   'Sci-Fi',
#   'Action',
#   'Adventure',
#   'Comedy',
#   'Romance',
#   'Biography',
#   'Thriller',
#   'Fantasy'],
#  'Sonoya Mizuno': ['Drama', 'Mystery', 'Sci-Fi'],
#  'Lena Headey': ['Action',
#   'Fantasy',
#   'War',
#   'Sci-Fi',
#   'Drama',
#   'Thriller',
#   'Horror'],
#  'David Wenham': ['Action', 'Fantasy', 'War'],
#  'Dominic West': ['Action',
#   'Fantasy',
#   'War',
#   'Crime',
#   'Drama',
#   'Thriller',
#   'Adventure'],
#  'Aaron Taylor-Johnson': ['Action',
#   'Comedy',
#   'Drama',
#   'Thriller',
#   'Crime',
#   'Romance',
#   'Adventure',
#   'Sci-Fi'],
#  'Nicolas Cage': ['Action',
#   'Comedy',
#   'Fantasy',
#   'Thriller',
#   'Drama',
#   'History'],
#  'Chloe Grace Moretz': ['Action',
#   'Comedy',
#   'Drama',
#   'Romance',
#   'Adventure',
#   'Family',
#   'Crime',
#   'Thriller',
#   'Horror',
#   'Mystery',
#   'Fantasy',
#   'Music',
#   'Sci-Fi'],
#  'Garrett M. Brown': ['Action', 'Comedy'],
#  'Anthony Edwards': ['Crime', 'Drama', 'History'],
#  'Lily James': ['Drama', 'Family', 'Fantasy', 'Action', 'Horror', 'Romance'],
#  'Jai Courtney': ['Drama',
#   'Adventure',
#   'Mystery',
#   'Sci-Fi',
#   'Action',
#   'Thriller'],
#  'Lois van Wijk': ['Drama'],
#  'Quinton Aaron': ['Biography', 'Drama', 'Sport'],
#  'Tim McGraw': ['Biography', 'Drama', 'Sport'],
#  'Jae Head': ['Biography', 'Drama', 'Sport', 'Action', 'Crime'],
#  'Jesse Eisenberg': ['Biography',
#   'Drama',
#   'Adventure',
#   'Comedy',
#   'Horror',
#   'Crime',
#   'Mystery',
#   'Thriller',
#   'Animation',
#   'Action',
#   'Sci-Fi',
#   'Romance'],
#  'Justin Timberlake': ['Biography',
#   'Drama',
#   'Action',
#   'Sci-Fi',
#   'Thriller',
#   'Comedy',
#   'Romance',
#   'Animation',
#   'Adventure'],
#  'Charlie Cox': ['Adventure', 'Family', 'Fantasy'],
#  'Claire Danes': ['Adventure', 'Family', 'Fantasy'],
#  'Sienna Miller': ['Adventure',
#   'Family',
#   'Fantasy',
#   'Action',
#   'Biography',
#   'Drama',
#   'Comedy'],
#  'Owen Wilson': ['Comedy',
#   'Fantasy',
#   'Romance',
#   'Animation',
#   'Adventure',
#   'Action',
#   'Thriller',
#   'Crime',
#   'Drama',
#   'Family'],
#  'Kathy Bates': ['Comedy', 'Fantasy', 'Romance'],
#  'Kurt Fuller': ['Comedy', 'Fantasy', 'Romance'],
#  'Eddie Redmayne': ['Biography',
#   'Drama',
#   'Romance',
#   'Adventure',
#   'Family',
#   'Fantasy',
#   'Action',
#   'Sci-Fi'],
#  'Tom Prior': ['Biography', 'Drama', 'Romance'],
#  'Sophie Perry': ['Biography', 'Drama', 'Romance'],
#  'Jason Segel': ['Animation', 'Adventure', 'Comedy', 'Drama', 'Romance'],
#  'Russell Brand': ['Animation', 'Adventure', 'Comedy'],
#  'Julie Andrews': ['Animation', 'Adventure', 'Comedy'],
#  'Dakota Fanning': ['Animation',
#   'Family',
#   'Fantasy',
#   'Mystery',
#   'Thriller',
#   'Western',
#   'Crime',
#   'Drama'],
#  'Teri Hatcher': ['Animation', 'Family', 'Fantasy'],
#  'John Hodgman': ['Animation', 'Family', 'Fantasy'],
#  'Jennifer Saunders': ['Animation', 'Family', 'Fantasy'],
#  'John Goodman': ['Biography',
#   'Drama',
#   'History',
#   'Thriller',
#   'Animation',
#   'Adventure',
#   'Comedy',
#   'Horror',
#   'Mystery',
#   'Crime'],
#  'Alan Arkin': ['Biography', 'Drama', 'History'],
#  'Giuseppe Battiston': ['Comedy', 'Drama'],
#  'Anna Foglietta': ['Comedy', 'Drama'],
#  'Marco Giallini': ['Comedy', 'Drama'],
#  'Edoardo Leo': ['Comedy', 'Drama'],
#  'Zooey Deschanel': ['Comedy',
#   'Drama',
#   'Romance',
#   'Adventure',
#   'Family',
#   'Animation',
#   'Sci-Fi',
#   'Thriller'],
#  'Geoffrey Arend': ['Comedy', 'Drama', 'Romance'],
#  'Naomi Watts': ['Crime',
#   'Drama',
#   'Mystery',
#   'Thriller',
#   'Comedy',
#   'Biography',
#   'Sport',
#   'Horror',
#   'Romance',
#   'Action',
#   'Adventure'],
#  'Armin Mueller-Stahl': ['Crime', 'Drama', 'Mystery'],
#  'Josef Altin': ['Crime', 'Drama', 'Mystery'],
#  'Michelle Monaghan': ['Crime',
#   'Drama',
#   'Mystery',
#   'Romance',
#   'Sci-Fi',
#   'History',
#   'Thriller',
#   'Action',
#   'Adventure',
#   'Comedy',
#   'Family'],
#  'Rosario Dawson': ['Drama',
#   'Romance',
#   'Thriller',
#   'Crime',
#   'Mystery',
#   'Action',
#   'Comedy'],
#  'Michael Ealy': ['Drama', 'Romance', 'Action', 'Fantasy', 'Horror'],
#  'Eddie Murphy': ['Comedy', 'Drama'],
#  'Britt Robertson': ['Comedy',
#   'Drama',
#   'Romance',
#   'Action',
#   'Adventure',
#   'Family'],
#  'Natascha McElhone': ['Comedy', 'Drama'],
#  'Xavier Samuel': ['Comedy', 'Drama', 'Romance', 'Adventure', 'Fantasy'],
#  'Rolf Lassgard': ['Comedy', 'Drama'],
#  'Bahar Pars': ['Comedy', 'Drama'],
#  'Filip Berg': ['Comedy', 'Drama'],
#  'Ida Engvoll': ['Comedy', 'Drama'],
#  'Seth Rogen': ['Comedy',
#   'Drama',
#   'Romance',
#   'Biography',
#   'Action',
#   'Crime',
#   'Adventure',
#   'Sci-Fi',
#   'Fantasy',
#   'Animation'],
#  'Anna Kendrick': ['Comedy',
#   'Drama',
#   'Romance',
#   'Crime',
#   'Thriller',
#   'Action',
#   'Music',
#   'Animation',
#   'Adventure'],
#  'Michael Pena': ['Crime',
#   'Drama',
#   'Thriller',
#   'Action',
#   'War',
#   'Romance',
#   'Comedy'],
#  'America Ferrera': ['Crime', 'Drama', 'Thriller'],
#  'Benedict Wong': ['Action', 'Adventure', 'Fantasy'],
#  'Jackie Earle Haley': ['Action', 'Drama', 'Mystery'],
#  'Patrick Wilson': ['Action',
#   'Drama',
#   'Mystery',
#   'Horror',
#   'Thriller',
#   'Adventure',
#   'Crime'],
#  'Carla Gugino': ['Action', 'Drama', 'Mystery', 'Adventure'],
#  'Malin Akerman': ['Action', 'Drama', 'Mystery', 'Comedy', 'Romance'],
#  'Michael Cera': ['Comedy', 'Action', 'Fantasy', 'Drama'],
#  'Benicio Del Toro': ['Action', 'Crime', 'Drama', 'Thriller'],
#  'Jon Bernthal': ['Action', 'Crime', 'Drama', 'Mystery', 'Thriller'],
#  'Keri Russell': ['Action', 'Adventure', 'Drama', 'Music', 'Biography'],
#  'Kodi Smit-McPhee': ['Action', 'Adventure', 'Drama', 'Horror', 'Mystery'],
#  'Shia LaBeouf': ['Action',
#   'Drama',
#   'War',
#   'Crime',
#   'Adventure',
#   'Sci-Fi',
#   'Mystery',
#   'Thriller',
#   'Fantasy'],
#  'Amanda Seyfried': ['Drama',
#   'Musical',
#   'Romance',
#   'Action',
#   'Sci-Fi',
#   'Thriller',
#   'Comedy',
#   'Family',
#   'Adventure',
#   'Western',
#   'Horror'],
#  'James Franco': ['Action',
#   'Drama',
#   'Sci-Fi',
#   'Adventure',
#   'Biography',
#   'Comedy',
#   'Crime',
#   'Fantasy',
#   'Family'],
#  'Karin Konoval': ['Action', 'Drama', 'Sci-Fi'],
#  'Jude Law': ['Action',
#   'Adventure',
#   'Crime',
#   'Comedy',
#   'Drama',
#   'Romance',
#   'Thriller',
#   'Biography'],
#  'Mark Strong': ['Action',
#   'Adventure',
#   'Crime',
#   'Drama',
#   'History',
#   'Thriller',
#   'Mystery',
#   'Romance',
#   'Comedy',
#   'Sci-Fi'],
#  'Michael B. Jordan': ['Drama',
#   'Sport',
#   'Comedy',
#   'Romance',
#   'Action',
#   'Adventure',
#   'Sci-Fi'],
#  'Sylvester Stallone': ['Drama',
#   'Sport',
#   'Action',
#   'Thriller',
#   'War',
#   'Crime',
#   'Mystery',
#   'Adventure'],
#  'Tessa Thompson': ['Drama', 'Sport', 'Comedy', 'Action'],
#  'Phylicia Rashad': ['Drama', 'Sport'],
#  'Jemaine Clement': ['Comedy',
#   'Fantasy',
#   'Horror',
#   'Action',
#   'Adventure',
#   'Family'],
#  'Taika Waititi': ['Comedy', 'Fantasy', 'Horror'],
#  'Cori Gonzalez-Macuer': ['Comedy', 'Fantasy', 'Horror'],
#  'Jonny Brugh': ['Comedy', 'Fantasy', 'Horror'],
#  'Mark Rylance': ['Drama',
#   'History',
#   'Thriller',
#   'Adventure',
#   'Family',
#   'Fantasy'],
#  'Alan Alda': ['Drama', 'History', 'Thriller', 'Romance'],
#  'Ewan McGregor': ['Drama', 'Thriller', 'Mystery', 'Crime'],
#  'Tom Holland': ['Drama', 'Thriller', 'Action', 'Adventure', 'Biography'],
#  'Oaklee Pendergast': ['Drama', 'Thriller'],
#  'Rebecca Hall': ['Crime',
#   'Drama',
#   'Thriller',
#   'Mystery',
#   'Romance',
#   'Biography'],
#  'Jon Hamm': ['Crime',
#   'Drama',
#   'Thriller',
#   'Animation',
#   'Action',
#   'Adventure',
#   'Comedy'],
#  'Josh Hutcherson': ['Action',
#   'Adventure',
#   'Mystery',
#   'Sci-Fi',
#   'Thriller',
#   'Drama',
#   'Family'],
#  'Liam Hemsworth': ['Action',
#   'Adventure',
#   'Mystery',
#   'Sci-Fi',
#   'Thriller',
#   'Comedy',
#   'Drama'],
#  'Philip Seymour Hoffman': ['Action',
#   'Adventure',
#   'Mystery',
#   'Biography',
#   'Drama',
#   'Sport',
#   'Thriller'],
#  'Robin Wright': ['Biography',
#   'Drama',
#   'Sport',
#   'Romance',
#   'Animation',
#   'Action',
#   'Adventure'],
#  'Sandra Huller': ['Comedy', 'Drama'],
#  'Peter Simonischek': ['Comedy', 'Drama'],
#  'Michael Wittenborn': ['Comedy', 'Drama'],
#  'Thomas Loibl': ['Comedy', 'Drama'],
#  'Anthony Mackie': ['Drama',
#   'History',
#   'Thriller',
#   'Action',
#   'Family',
#   'Biography',
#   'Crime',
#   'Comedy'],
#  'Brian Geraghty': ['Drama', 'History', 'Thriller'],
#  'Guy Pearce': ['Drama',
#   'History',
#   'Thriller',
#   'Crime',
#   'Action',
#   'Adventure',
#   'Sci-Fi',
#   'Mystery',
#   'Western'],
#  'Stuart Graham': ['Biography', 'Drama'],
#  'Laine Megaw': ['Biography', 'Drama'],
#  'Brian Milligan': ['Biography', 'Drama'],
#  'Liam McMahon': ['Biography', 'Drama'],
#  'Emmanuel Garijo': ['Animation', 'Fantasy'],
#  'Tom Hudson': ['Animation', 'Fantasy'],
#  'Baptiste Goy': ['Animation', 'Fantasy'],
#  'Axel Devillers': ['Animation', 'Fantasy'],
#  'Jessica Biel': ['Drama',
#   'Mystery',
#   'Romance',
#   'Action',
#   'Adventure',
#   'Comedy',
#   'Crime',
#   'Thriller'],
#  'Paul Giamatti': ['Drama',
#   'Mystery',
#   'Romance',
#   'Action',
#   'Adventure',
#   'Sci-Fi',
#   'Fantasy'],
#  'Rufus Sewell': ['Drama', 'Mystery', 'Romance'],
#  'Hailee Steinfeld': ['Adventure',
#   'Drama',
#   'Western',
#   'Comedy',
#   'Music',
#   'Action',
#   'Sci-Fi',
#   'Thriller'],
#  'Jodie Foster': ['Crime', 'Drama', 'Mystery', 'Action', 'Sci-Fi'],
#  'Amber Tamblyn': ['Adventure', 'Biography', 'Drama'],
#  'Sean Bott': ['Adventure', 'Biography', 'Drama'],
#  'Rose McGowan': ['Action',
#   'Horror',
#   'Thriller',
#   'Comedy',
#   'Adventure',
#   'Fantasy'],
#  'Danny Trejo': ['Action', 'Horror', 'Thriller'],
#  'Zoe Bell': ['Action', 'Horror', 'Thriller'],
#  'Jack Black': ['Animation', 'Action', 'Adventure', 'Comedy', 'Family'],
#  'Ian McShane': ['Animation',
#   'Action',
#   'Adventure',
#   'Fantasy',
#   'Sci-Fi',
#   'Thriller'],
#  'Dustin Hoffman': ['Animation',
#   'Action',
#   'Adventure',
#   'Crime',
#   'Drama',
#   'Fantasy',
#   'Comedy'],
#  'Antonio Banderas': ['Drama', 'Thriller', 'Action', 'Adventure'],
#  'Elena Anaya': ['Drama', 'Thriller'],
#  'Jan Cornet': ['Drama', 'Thriller'],
#  'Marisa Paredes': ['Drama', 'Thriller'],
#  'Katherine Waterston': ['Adventure',
#   'Family',
#   'Fantasy',
#   'Comedy',
#   'Crime',
#   'Drama'],
#  'Alison Sudol': ['Adventure', 'Family', 'Fantasy'],
#  'Dan Fogler': ['Adventure',
#   'Family',
#   'Fantasy',
#   'Comedy',
#   'Drama',
#   'Romance'],
#  'Michael Shannon': ['Drama',
#   'Thriller',
#   'Action',
#   'Adventure',
#   'Fantasy',
#   'Mystery',
#   'Sci-Fi'],
#  'Mahershala Ali': ['Drama', 'Action', 'Biography'],
#  'Shariff Earp': ['Drama'],
#  'Duan Sanderson': ['Drama'],
#  'Alex R. Hibbert': ['Drama'],
#  'Laura Linney': ['Biography', 'Drama', 'Action', 'Adventure', 'Comedy'],
#  'Valerie Mahaffey': ['Biography', 'Drama'],
#  "Beverly D'Angelo": ['Drama'],
#  "Jason O'Mara": ['Drama', 'Action', 'Thriller'],
#  'Lewis MacDougall': ['Drama', 'Fantasy'],
#  'Toby Kebbell': ['Drama', 'Fantasy', 'Action', 'Adventure'],
#  'Neel Sethi': ['Adventure', 'Drama', 'Family'],
#  'Mary Elizabeth Winstead': ['Action',
#   'Comedy',
#   'Fantasy',
#   'Drama',
#   'Horror',
#   'Mystery',
#   'Adventure'],
#  'Kieran Culkin': ['Action', 'Comedy', 'Fantasy'],
#  'Alison Pill': ['Action', 'Comedy', 'Fantasy'],
#  'Kristen Bell': ['Animation', 'Adventure', 'Comedy', 'Drama', 'Romance'],
#  'Idina Menzel': ['Animation', 'Adventure', 'Comedy'],
#  'Jonathan Groff': ['Animation', 'Adventure', 'Comedy'],
#  'Josh Gad': ['Animation', 'Adventure', 'Comedy', 'Action'],
#  'Garance Marillier': ['Drama', 'Horror'],
#  'Ella Rumpf': ['Drama', 'Horror'],
#  'Rabah Nait Oufella': ['Drama', 'Horror'],
#  'Laurent Lucas': ['Drama', 'Horror', 'Adventure', 'Biography'],
#  'Adam Driver': ['Comedy',
#   'Drama',
#   'Romance',
#   'Adventure',
#   'History',
#   'Mystery',
#   'Sci-Fi'],
# ...
#  'David Denman': ['Action', 'Drama', 'History', 'Adventure', 'Sci-Fi'],
#  'Michael Douglas': ['Action', 'Adventure', 'Comedy'],
#  'Corey Stoll': ['Action', 'Adventure', 'Comedy', 'Drama', 'Thriller'],
#  'Evangeline Lilly': ['Action', 'Adventure', 'Comedy', 'Drama', 'Family'],
#  'Christos Stergioglou': ['Drama', 'Thriller'],
#  'Michele Valley': ['Drama', 'Thriller'],
#  'Angeliki Papoulia': ['Drama', 'Thriller'],
#  'Hristos Passalis': ['Drama', 'Thriller'],
#  'Common': ['Crime', 'Mystery', 'Thriller'],
#  'Paul Walker': ['Action', 'Crime', 'Thriller'],
#  'Jordana Brewster': ['Action', 'Crime', 'Thriller'],
#  'Tom Wilkinson': ['Action',
#   'Crime',
#   'Thriller',
#   'Comedy',
#   'Drama',
#   'Fantasy',
#   'Biography',
#   'Adventure',
#   'Western'],
#  'Kyle Gallner': ['Action', 'Biography', 'Drama', 'Comedy'],
#  'Cole Konis': ['Action', 'Biography', 'Drama'],
#  'Florence Pugh': ['Drama'],
#  'Christopher Fairbank': ['Drama'],
#  'Cosmo Jarvis': ['Drama'],
#  'Naomi Ackie': ['Drama'],
#  'Billy Crystal': ['Animation', 'Adventure', 'Comedy'],
#  'Steve Buscemi': ['Animation', 'Adventure', 'Comedy'],
#  'Kate Winslet': ['Drama',
#   'Romance',
#   'Biography',
#   'Comedy',
#   'Adventure',
#   'Mystery',
#   'Sci-Fi',
#   'Thriller'],
#  'Christopher Fitzgerald': ['Drama', 'Romance'],
#  'Jonathan Roumie': ['Drama', 'Romance'],
#  'Harvey Keitel': ['Comedy', 'Drama', 'Music'],
#  'Rachel Weisz': ['Comedy',
#   'Drama',
#   'Music',
#   'Sci-Fi',
#   'Romance',
#   'Action',
#   'Adventure',
#   'Mystery',
#   'Fantasy',
#   'Thriller',
#   'Biography',
#   'Family'],
#  'Jane Fonda': ['Comedy', 'Drama', 'Music', 'Biography'],
#  'Jim Carrey': ['Crime',
#   'Drama',
#   'Thriller',
#   'Action',
#   'Comedy',
#   'Romance',
#   'Sci-Fi'],
#  'Charlotte Gainsbourg': ['Crime', 'Drama', 'Thriller', 'Horror'],
#  'Marton Csokas': ['Crime', 'Drama', 'Thriller', 'Action'],
#  'Kati Outinen': ['Crime', 'Drama', 'Thriller'],
#  'Cillian Murphy': ['Adventure',
#   'Sci-Fi',
#   'Thriller',
#   'Biography',
#   'History',
#   'Action',
#   'Comedy',
#   'Crime',
#   'Drama',
#   'Mystery',
#   'Romance'],
#  'Rose Byrne': ['Adventure',
#   'Sci-Fi',
#   'Thriller',
#   'Action',
#   'Comedy',
#   'Crime',
#   'Drama',
#   'Horror',
#   'Romance',
#   'Mystery',
#   'Family'],
#  'Michelle Yeoh': ['Adventure',
#   'Sci-Fi',
#   'Thriller',
#   'Action',
#   'Crime',
#   'Fantasy'],
#  'Tina Fey': ['Animation', 'Action', 'Comedy', 'Biography', 'Drama'],
#  'Ben Stiller': ['Adventure',
#   'Comedy',
#   'Drama',
#   'Action',
#   'Family',
#   'Romance'],
#  'Jon Daly': ['Adventure', 'Comedy', 'Drama'],
#  'Kathryn Hahn': ['Adventure', 'Comedy', 'Drama', 'Action'],
#  'Shameik Moore': ['Comedy', 'Crime', 'Drama'],
#  'Tony Revolori': ['Comedy', 'Crime', 'Drama'],
#  'Kiersey Clemons': ['Comedy', 'Crime', 'Drama'],
#  'Kimberly Elise': ['Comedy', 'Crime', 'Drama'],
#  'Jason Clarke': ['Crime',
#   'Drama',
#   'Action',
#   'Adventure',
#   'Thriller',
#   'Biography',
#   'Sci-Fi'],
#  'Michael Pitt': ['Drama', 'Romance', 'Sci-Fi', 'Crime', 'Horror'],
#  'Steven Yeun': ['Drama', 'Romance', 'Sci-Fi'],
#  'Astrid Berges-Frisbey': ['Drama', 'Romance', 'Sci-Fi'],
#  'Brit Marling': ['Drama', 'Romance', 'Sci-Fi'],
#  'Channing Tatum': ['Animation',
#   'Adventure',
#   'Comedy',
#   'Action',
#   'Crime',
#   'Drama',
#   'Music',
#   'Thriller',
#   'Romance',
#   'Sport',
#   'Sci-Fi'],
#  'Jon Favreau': ['Comedy', 'Drama', 'Romance'],
#  'Aaron Paul': ['Drama', 'Thriller', 'War', 'Action', 'Crime', 'Mystery'],
#  'Sean Patrick Thomas': ['Drama', 'Sci-Fi'],
#  'Ellen Burstyn': ['Drama', 'Sci-Fi'],
#  'Demi Moore': ['Crime', 'Drama', 'Thriller'],
#  'William Hurt': ['Crime',
#   'Drama',
#   'Thriller',
#   'Action',
#   'Adventure',
#   'Sci-Fi'],
#  'Dane Cook': ['Crime', 'Drama', 'Thriller'],
#  'Jeremy Davies': ['Adventure', 'Biography', 'Drama'],
#  'Zach Grenier': ['Adventure', 'Biography', 'Drama'],
#  'Nadine Velazquez': ['Drama', 'Thriller', 'Horror'],
#  'Don Cheadle': ['Drama', 'Thriller', 'Action', 'Adventure', 'Sci-Fi'],
#  'Alec Baldwin': ['Drama',
#   'Biography',
#   'Sport',
#   'Comedy',
#   'Musical',
#   'Romance'],
#  'Peter Sarsgaard': ['Drama',
#   'Horror',
#   'Mystery',
#   'Thriller',
#   'Biography',
#   'History',
#   'Action',
#   'Adventure',
#   'Sci-Fi'],
#  'Gabourey Sidibe': ['Drama'],
#  "Mo'Nique": ['Drama'],
#  'Mariah Carey': ['Drama'],
#  'Jamie Dornan': ['Action',
#   'Drama',
#   'Thriller',
#   'Biography',
#   'History',
#   'Mystery',
#   'Romance'],
#  'Michael McElhatton': ['Action', 'Drama', 'Thriller', 'Horror', 'Mystery'],
#  'Amara Miller': ['Comedy', 'Drama'],
#  'Nick Krause': ['Comedy', 'Drama'],
#  'Charlotte Le Bon': ['Adventure',
#   'Biography',
#   'Crime',
#   'Action',
#   'Drama',
#   'Thriller',
#   'History',
#   'Sci-Fi'],
#  'Guillaume Baillargeon': ['Adventure', 'Biography', 'Crime'],
#  'Emilie Leclerc': ['Adventure', 'Biography', 'Crime'],
#  'Reese Witherspoon': ['Animation',
#   'Comedy',
#   'Family',
#   'Adventure',
#   'Biography',
#   'Drama',
#   'Action',
#   'Romance',
#   'Crime'],
#  'Seth MacFarlane': ['Animation',
#   'Comedy',
#   'Family',
#   'Fantasy',
#   'Adventure',
#   'Romance',
#   'Western'],
#  'John Carroll Lynch': ['Biography', 'Drama', 'History'],
#  'Linda Cardellini': ['Biography', 'Drama', 'History', 'Comedy', 'Family'],
#  'Keanu Reeves': ['Action',
#   'Crime',
#   'Thriller',
#   'Horror',
#   'Romance',
#   'Sci-Fi',
#   'Drama',
#   'Mystery'],
#  'Alfie Allen': ['Action', 'Crime', 'Thriller'],
#  'Willem Dafoe': ['Action',
#   'Crime',
#   'Thriller',
#   'Drama',
#   'Adventure',
#   'Sci-Fi',
#   'Horror',
#   'Fantasy'],
#  'Stephen Lang': ['Crime',
#   'Horror',
#   'Thriller',
#   'Action',
#   'Adventure',
#   'Fantasy'],
#  'Jane Levy': ['Crime',
#   'Horror',
#   'Thriller',
#   'Fantasy',
#   'Action',
#   'Adventure',
#   'Comedy'],
#  'Dylan Minnette': ['Crime',
#   'Horror',
#   'Thriller',
#   'Adventure',
#   'Comedy',
#   'Family'],
#  'Daniel Zovatto': ['Crime', 'Horror', 'Thriller'],
#  'Douglas M. Griffin': ['Action', 'Drama', 'Thriller', 'Horror', 'Mystery'],
#  'James DuMont': ['Action', 'Drama', 'Thriller'],
#  'Jason Statham': ['Action',
#   'Crime',
#   'Thriller',
#   'Comedy',
#   'Adventure',
#   'Sci-Fi'],
#  'John Gallagher Jr.': ['Drama', 'Horror', 'Mystery', 'Thriller', 'Action'],
#  'Stanley Tucci': ['Adventure', 'Sci-Fi', 'Thriller', 'Action'],
#  'Florence Clery': ['Drama', 'Romance'],
#  'Ice Cube': ['Action', 'Comedy', 'Crime', 'Drama'],
#  'Brittany Snow': ['Comedy', 'Music', 'Romance'],
#  'Rebel Wilson': ['Comedy', 'Music', 'Romance', 'Action', 'Adventure'],
#  'Anna Camp': ['Comedy', 'Music', 'Romance'],
#  'David Harbour': ['Action', 'Crime', 'Thriller', 'Drama', 'Mystery'],
#  'Jeff Daniels': ['Biography', 'Drama', 'Action', 'Adventure', 'Mystery'],
#  'Blake Lively': ['Drama',
#   'Fantasy',
#   'Romance',
#   'Comedy',
#   'Crime',
#   'Thriller',
#   'Horror',
#   'Action',
#   'Adventure',
#   'Sci-Fi'],
#  'Michiel Huisman': ['Drama',
#   'Fantasy',
#   'Romance',
#   'Adventure',
#   'Biography',
#   'Mystery',
#   'Thriller'],
#  'Kathy Baker': ['Drama', 'Fantasy', 'Romance'],
#  'Isabelle Huppert': ['Crime', 'Drama', 'Thriller'],
#  'Laurent Lafitte': ['Crime', 'Drama', 'Thriller'],
#  'Anne Consigny': ['Crime', 'Drama', 'Thriller'],
#  'Charles Berling': ['Crime', 'Drama', 'Thriller'],
#  'Lucy Walters': ['Drama'],
#  'Alice Braga': ['Drama', 'Horror', 'Sci-Fi', 'Action', 'Adventure'],
#  'Charlie Tahan': ['Drama', 'Horror', 'Sci-Fi'],
#  'Salli Richardson-Whitfield': ['Drama', 'Horror', 'Sci-Fi'],
#  'Sarah Paulson': ['Drama', 'Romance'],
#  'Rhona Mitra': ['Action', 'Crime', 'Drama', 'Adventure', 'Fantasy'],
#  'Danny Glover': ['Action', 'Crime', 'Drama'],
#  'Brian Caspe': ['Biography', 'History', 'Thriller'],
#  'Karel Hermanek Jr.': ['Biography', 'History', 'Thriller'],
#  'Cynthia Nixon': ['Biography', 'Drama', 'Comedy', 'Romance'],
#  'Jennifer Ehle': ['Biography', 'Drama', 'Romance', 'Thriller'],
#  'Duncan Duff': ['Biography', 'Drama'],
#  'Keith Carradine': ['Biography', 'Drama'],
#  'Pierce Brosnan': ['Mystery',
#   'Thriller',
#   'Action',
#   'Comedy',
#   'Family',
#   'Musical',
#   'Crime',
#   'Drama'],
#  'Olivia Williams': ['Mystery', 'Thriller'],
#  "Jack O'Connell": ['Biography', 'Drama', 'Sport', 'Crime', 'Thriller'],
#  'Miyavi': ['Biography', 'Drama', 'Sport'],
#  'Garrett Hedlund': ['Biography',
#   'Drama',
#   'Sport',
#   'Action',
#   'Adventure',
#   'Sci-Fi',
#   'War',
#   'Family',
#   'Fantasy'],
#  'Kelly Macdonald': ['Animation', 'Adventure', 'Comedy'],
#  'Billy Connolly': ['Animation', 'Adventure', 'Comedy'],
#  'Julie Walters': ['Animation', 'Adventure', 'Comedy'],
#  'Richard Jenkins': ['Drama',
#   'Horror',
#   'Mystery',
#   'Adventure',
#   'Action',
#   'Crime',
#   'Comedy',
#   'Romance'],
#  'Cara Buono': ['Drama', 'Horror', 'Mystery'],
#  'John Hawkes': ['Drama'],
#  'Garret Dillahunt': ['Drama'],
#  'Isaiah Stone': ['Drama'],
#  'Thomas Jane': ['Horror', 'Drama', 'Fantasy', 'Action', 'History'],
#  'Laurie Holden': ['Horror', 'Adventure', 'Mystery'],
#  'Andre Braugher': ['Horror'],
#  'Lily Collins': ['Comedy', 'Romance', 'Action', 'Fantasy', 'Horror', 'Drama'],
#  'Christian Cooke': ['Comedy', 'Romance'],
#  'Jaime Winstone': ['Comedy', 'Romance'],
#  'Byung-hun Lee': ['Action', 'Drama', 'Thriller', 'Adventure', 'Sci-Fi'],
#  'Kang-ho Song': ['Action', 'Drama', 'Thriller', 'Comedy', 'Horror'],
#  'Ji-min Han': ['Action', 'Drama', 'Thriller'],
#  'Justin Long': ['Action',
#   'Adventure',
#   'Thriller',
#   'Comedy',
#   'Drama',
#   'Horror'],
#  'Timothy Olyphant': ['Action', 'Adventure', 'Thriller', 'Sci-Fi'],
#  'Maggie Q': ['Action', 'Adventure', 'Thriller'],
#  'Anthony Hopkins': ['Crime',
#   'Drama',
#   'Mystery',
#   'Action',
#   'Adventure',
#   'Fantasy',
#   'Thriller'],
#  'Jeremy Irons': ['Biography',
#   'Drama',
#   'Mystery',
#   'Thriller',
#   'Action',
#   'Adventure'],
#  'Malcolm Sinclair': ['Biography', 'Drama'],
#  'Raghuvir Joshi': ['Biography', 'Drama'],
#  'Christopher Walken': ['Comedy', 'Crime'],
#  'Antonio Tarver': ['Drama', 'Sport'],
#  'Milo Ventimiglia': ['Drama', 'Sport'],
#  'Burt Young': ['Drama', 'Sport'],
#  'Robert Pattinson': ['Drama',
#   'Romance',
#   'Action',
#   'Adventure',
#   'Biography',
#   'Fantasy'],
#  'Emilie de Ravin': ['Drama', 'Romance', 'Horror'],
#  'Caitlyn Rund': ['Drama', 'Romance'],
#  'Moises Acevedo': ['Drama', 'Romance'],
#  'AnnaSophia Robb': ['Adventure', 'Drama', 'Family'],
#  'Robert Patrick': ['Adventure', 'Drama', 'Family', 'Romance'],
#  'Emily Baldoni': ['Mystery', 'Sci-Fi', 'Thriller'],
#  'Maury Sterling': ['Mystery', 'Sci-Fi', 'Thriller'],
#  'Nicholas Brendon': ['Mystery', 'Sci-Fi', 'Thriller'],
#  'Elizabeth Gracen': ['Mystery', 'Sci-Fi', 'Thriller'],
#  'Oprah Winfrey': ['Biography', 'Drama', 'Animation', 'Adventure', 'Comedy'],
#  'John Cusack': ['Biography',
#   'Drama',
#   'Fantasy',
#   'Horror',
#   'Action',
#   'Adventure',
#   'Sci-Fi'],
#  'Nick Robinson': ['Adventure', 'Comedy', 'Drama'],
#  'Gabriel Basso': ['Adventure',
#   'Comedy',
#   'Drama',
#   'Sport',
#   'Crime',
#   'Mystery'],
#  'Moises Arias': ['Adventure', 'Comedy', 'Drama'],
#  'Charlie Hunnam': ['Action',
#   'Adventure',
#   'Biography',
#   'Sci-Fi',
#   'Drama',
#   'Fantasy',
#   'Horror'],
#  'John Francis Daley': ['Comedy', 'Drama'],
#  'Austin Pendleton': ['Comedy', 'Drama'],
#  'Colleen Camp': ['Comedy', 'Drama'],
#  'Neil Flynn': ['Comedy', 'Drama'],
#  'Karl Urban': ['Action',
#   'Adventure',
#   'Sci-Fi',
#   'Thriller',
#   'Mystery',
#   'Romance'],
#  'Marion Cotillard': ['Action',
#   'Drama',
#   'Romance',
#   'Comedy',
#   'War',
#   'Adventure'],
#  'Vincent Ebrahim': ['Action', 'Drama', 'Romance'],
#  'Steve Lantz': ['Comedy', 'Crime', 'Drama'],
#  'Gregg Weiner': ['Comedy', 'Crime', 'Drama'],
#  'Kit Harington': ['Mystery',
#   'Thriller',
#   'Western',
#   'Action',
#   'Adventure',
#   'Drama'],
#  'Carice van Houten': ['Mystery', 'Thriller', 'Western'],
#  'Megan Fox': ['Action', 'Adventure', 'Sci-Fi', 'Comedy', 'Horror'],
#  'Josh Duhamel': ['Action',
#   'Adventure',
#   'Sci-Fi',
#   'Drama',
#   'Romance',
#   'Thriller',
#   'Comedy'],
#  'Tyrese Gibson': ['Action', 'Adventure', 'Sci-Fi', 'Thriller'],
#  'Bonnie Hunt': ['Animation', 'Adventure', 'Comedy'],
#  'Paul Newman': ['Animation', 'Adventure', 'Comedy'],
#  'Larry the Cable Guy': ['Animation', 'Adventure', 'Comedy'],
#  'Jessica Barden': ['Comedy', 'Drama', 'Romance'],
#  'Olivia Colman': ['Comedy', 'Drama', 'Romance'],
#  'Melissa McCarthy': ['Action', 'Comedy', 'Crime', 'Fantasy'],
#  'Lior Ashkenazi': ['Drama', 'Thriller'],
#  'Michael Sheen': ['Drama',
#   'Thriller',
#   'Adventure',
#   'Romance',
#   'Action',
#   'Fantasy'],
#  'Vanessa Ferlito': ['Thriller'],
#  'Diane Lane': ['Action',
#   'Adventure',
#   'Fantasy',
#   'Comedy',
#   'Drama',
#   'Romance'],
#  'John Leguizamo': ['Biography',
#   'Crime',
#   'Drama',
#   'Animation',
#   'Adventure',
#   'Comedy',
#   'Sci-Fi',
#   'Thriller'],
#  'Judy Davis': ['Comedy', 'Drama', 'Biography', 'History'],
#  'Antonia Ribero': ['Adventure', 'Comedy', 'Drama'],
#  'Ang Phula Sherpa': ['Action', 'Adventure', 'Drama'],
#  'Thomas M. Wright': ['Action', 'Adventure', 'Drama'],
#  'Martin Henderson': ['Action', 'Adventure', 'Drama', 'Biography', 'Family'],
#  'Kelly Adams': ['Action', 'Biography', 'Crime'],
#  'Luing Andrews': ['Action', 'Biography', 'Crime'],
#  'Katy Barker': ['Action', 'Biography', 'Crime'],
#  'Eddie Marsan': ['Comedy', 'Crime', 'Drama'],
#  'Imogen Poots': ['Comedy',
#   'Crime',
#   'Drama',
#   'Horror',
#   'Thriller',
#   'Action',
#   'Romance'],
#  'Scott Eastwood': ['Drama', 'Romance', 'Horror', 'Thriller'],
#  'Jack Huston': ['Drama',
#   'Romance',
#   'Comedy',
#   'Action',
#   'Horror',
#   'Adventure'],
#  'Olivia Thirlby': ['Action', 'Sci-Fi', 'Biography', 'Drama', 'History'],
#  'Rachel Wood': ['Action', 'Sci-Fi'],
#  'AJ Michalka': ['Mystery', 'Sci-Fi', 'Thriller'],
#  'Joel Courtney': ['Mystery', 'Sci-Fi', 'Thriller'],
#  'Matthew Fox': ['Adventure', 'Drama', 'Horror'],
#  'Amanda Bynes': ['Comedy', 'Drama', 'Romance', 'Sport'],
#  'Penn Badgley': ['Comedy', 'Drama', 'Romance'],
#  'Dan Byrd': ['Comedy', 'Drama', 'Romance', 'Horror'],
#  'Harry Connick Jr.': ['Drama', 'Romance'],
#  'Lisa Kudrow': ['Drama', 'Romance', 'Comedy'],
#  'Ruth Negga': ['Biography', 'Drama', 'Romance'],
#  'Will Dalton': ['Biography', 'Drama', 'Romance'],
#  'Dean Mumford': ['Biography', 'Drama', 'Romance'],
#  'Richenda Carey': ['Drama', 'Romance', 'Thriller'],
#  'Allison Tolman': ['Mystery', 'Thriller'],
#  'Susan Sarandon': ['Animation',
#   'Comedy',
#   'Family',
#   'Drama',
#   'Fantasy',
#   'Thriller'],
#  'James Marsden': ['Animation',
#   'Comedy',
#   'Family',
#   'Drama',
#   'Romance',
#   'Mystery',
#   'Thriller',
#   'Action',
#   'Adventure',
#   'Sci-Fi'],
#  'Anders Holm': ['Comedy', 'Drama'],
#  'James Gandolfini': ['Crime', 'Drama', 'Mystery'],
#  'Matthias Schoenaerts': ['Crime', 'Drama', 'Mystery', 'Thriller'],
#  'Andre Marcon': ['Drama'],
#  'Roman Kolinka': ['Drama'],
#  'Edith Scob': ['Drama'],
#  'Lisa Thoreson': ['Romance', 'Sci-Fi', 'Thriller'],
#  'Florence Kastriner': ['Romance', 'Sci-Fi', 'Thriller'],
#  'Gaby Hoffmann': ['Adventure', 'Biography', 'Drama'],
#  'Kirsten Dunst': ['Drama',
#   'Mystery',
#   'Sci-Fi',
#   'Biography',
#   'History',
#   'Crime',
#   'Action',
#   'Adventure'],
#  'Alexander Skarsgard': ['Drama', 'Action', 'Adventure', 'Comedy', 'Sci-Fi'],
#  'Anika Noni Rose': ['Animation', 'Adventure', 'Comedy', 'Drama', 'Romance'],
#  'Keith David': ['Animation', 'Adventure', 'Comedy'],
#  'Bruno Campos': ['Animation', 'Adventure', 'Comedy'],
#  'Christopher Evan Welch': ['Drama', 'Romance'],
#  'Ruth Wilson': ['Drama', 'Thriller'],
#  'Dakota Goyo': ['Action', 'Drama', 'Family'],
#  'Julie Benz': ['Action', 'Thriller', 'War'],
#  'Matthew Marsden': ['Action', 'Thriller', 'War'],
#  'Graham McTavish': ['Action', 'Thriller', 'War'],
#  'Freddy Rodriguez': ['Action', 'Comedy', 'Horror'],
#  'Marley Shelton': ['Action', 'Comedy', 'Horror'],
#  'David Morse': ['Biography', 'Drama', 'Sport', 'Mystery', 'Thriller'],
#  'Jesse Plemons': ['Drama'],
#  'Morjana Alaoui': ['Horror'],
#  'Mylene Jampanoi': ['Horror'],
#  'Catherine Begin': ['Horror'],
#  'Robert Toupin': ['Horror'],
#  'Logan Marshall-Green': ['Adventure',
#   'Mystery',
#   'Sci-Fi',
#   'Drama',
#   'Thriller'],
#  'Laurence Fishburne': ['Adventure', 'Drama', 'Romance', 'Action', 'Sci-Fi'],
#  'Gemma Arterton': ['Comedy',
#   'Drama',
#   'Romance',
#   'Horror',
#   'Thriller',
#   'Action',
#   'Adventure',
#   'Fantasy'],
#  'Ty Simpkins': ['Action',
#   'Adventure',
#   'Sci-Fi',
#   'Horror',
#   'Mystery',
#   'Thriller'],
#  'Judy Greer': ['Action', 'Adventure', 'Sci-Fi', 'Comedy', 'Drama', 'Romance'],
#  'Travis Fimmel': ['Action', 'Adventure', 'Fantasy'],
#  ...}

# %% [markdown]
# ##### answer

# %%
count_actor_genre = {}
for k, v in actor_genre.items():
    count_actor_genre[k] = len(v)
count_actor_genre = {k: v for k, v in sorted(count_actor_genre.items(), key=lambda item: item[1], reverse=True)}
top_count_actor_genre = [(k, v) for k, v in count_actor_genre.items()]
print(f'Top actors playing in the most genres of movies:\n{[i for i, j in top_count_actor_genre if j >= 13]}\n')
# Out:
# Top actors playing in the most genres of movies:
# ['Brad Pitt', 'Hugh Jackman', 'Scarlett Johansson', 'Amy Adams', 'Chloe Grace Moretz', 'Johnny Depp']

# %% [markdown]
# # (6) Top-3 actors whose movies lead to the largest maximum gap of years?

# %% [markdown]
# Example of “maximum gap of years”:
#
# Tom Cruise has movies: “Edge of Tomorrow” in 2014, “Mission: Impossible - Rogue Nation” in 2015, “Oblivion” in 2013, “Jack Reacher” in 2012, “Mission: Impossible III” in 2006, “Jack Reacher: Never Go Back” in 2016, “Rock of Ages” in 2012, “Mission: Impossible - Ghost Protocol” in 2011.
#
# The maximum gap of years is 2016‐2006 = 10

# %%
index_a, index_y = df.multi_col_name_index('Actors', 'Year')
g_a = []
for i in df.rows:
    i[index_a] = i[index_a].replace('|', ',')
    i[index_a] = i[index_a].replace(', ', ',')
    g_a.append((int(i[index_y]), i[index_a].split(',')))
print(g_a[:3])
# Out:
# [(2008, ['Christian Bale', 'Heath Ledger', 'Aaron Eckhart', 'Michael Caine']), (2010, ['Leonardo DiCaprio', 'Joseph Gordon-Levitt', 'Ellen Page', 'Ken Watanabe']), (2016, ['Aamir Khan', 'Sakshi Tanwar', 'Fatima Sana Shaikh', 'Sanya Malhotra'])]

# %%
actor_year = {}
for year, actors in g_a:
    for actor in actors:
        if actor not in actor_year:
            actor_year[actor] = [year]
        else:
            actor_year[actor].append(year)
actor_year
# Out:
# {'Christian Bale': [2008,
#   2006,
#   2012,
#   2015,
#   2010,
#   2013,
#   2006,
#   2009,
#   2013,
#   2009,
#   2014,
#   2016,
#   2015],
#  'Heath Ledger': [2008, 2009],
#  'Aaron Eckhart': [2008, 2016, 2016, 2013, 2016],
#  'Michael Caine': [2008, 2006, 2006, 2014, 2015, 2011],
#  'Leonardo DiCaprio': [2010,
#   2006,
#   2012,
#   2013,
#   2010,
#   2015,
#   2006,
#   2013,
#   2008,
#   2008],
#  'Joseph Gordon-Levitt': [2010,
#   2009,
#   2011,
#   2012,
#   2012,
#   2016,
#   2015,
#   2013,
#   2014],
#  'Ellen Page': [2010, 2007, 2010, 2012, 2015],
#  'Ken Watanabe': [2010, 2014, 2015],
#  'Aamir Khan': [2016, 2007, 2009, 2014],
#  'Sakshi Tanwar': [2016],
#  'Fatima Sana Shaikh': [2016],
#  'Sanya Malhotra': [2016],
#  'Matthew McConaughey': [2014,
#   2013,
#   2013,
#   2016,
#   2016,
#   2016,
#   2016,
#   2012,
#   2015,
#   2008],
#  'Anne Hathaway': [2014,
#   2012,
#   2012,
#   2015,
#   2011,
#   2011,
#   2006,
#   2010,
#   2010,
#   2016,
#   2016,
#   2009],
#  'Jessica Chastain': [2014, 2015, 2012, 2016, 2011, 2015, 2013, 2016],
#  'Mackenzie Foy': [2014],
#  'Ryunosuke Kamiki': [2016],
#  'Mone Kamishiraishi': [2016],
#  'Ryo Narita': [2016],
#  'Aoi Yuki': [2016, 2016],
#  'Francois Cluzet': [2011],
#  'Omar Sy': [2011, 2016],
#  'Anne Le Ny': [2011],
#  'Audrey Fleurot': [2011],
#  'Hugh Jackman': [2006,
#   2013,
#   2014,
#   2012,
#   2016,
#   2006,
#   2011,
#   2015,
#   2009,
#   2013,
#   2006,
#   2008,
#   2006,
#   2015],
#  'Scarlett Johansson': [2006,
#   2012,
#   2013,
#   2016,
#   2014,
#   2014,
#   2016,
#   2008,
#   2008,
#   2013,
#   2014,
#   2013],
#  'Matt Damon': [2006, 2007, 2015, 2010, 2011, 2007, 2016, 2013, 2011, 2016],
#  'Jack Nicholson': [2006],
#  'Mark Wahlberg': [2006,
#   2010,
#   2013,
#   2016,
#   2016,
#   2007,
#   2012,
#   2010,
#   2009,
#   2013,
#   2015,
#   2015,
#   2014,
#   2014,
#   2008],
#  'Tom Hardy': [2012,
#   2011,
#   2015,
#   2015,
#   2012,
#   2008,
#   2014,
#   2011,
#   2013,
#   2015,
#   2015,
#   2012],
#  'Gary Oldman': [2012, 2014, 2011, 2010, 2015, 2016, 2014, 2015],
#  'Miles Teller': [2014, 2016, 2013, 2016, 2014, 2015],
#  'J.K. Simmons': [2014, 2016, 2016, 2016, 2016],
#  'Melissa Benoist': [2014],
#  'Paul Reiser': [2014],
#  'Ulrich Muhe': [2006],
#  'Martina Gedeck': [2006],
#  'Sebastian Koch': [2006],
#  'Ulrich Tukur': [2006],
#  'Darsheel Safary': [2007],
#  'Tanay Chheda': [2007],
#  'Sachet Engineer': [2007],
#  'Jamie Foxx': [2012, 2009, 2014, 2013, 2014],
#  'Christoph Waltz': [2012, 2015, 2016],
#  'Kerry Washington': [2012],
#  'Madhavan': [2009],
#  'Mona Singh': [2009],
#  'Sharman Joshi': [2009],
#  'Ben Burtt': [2008],
#  'Elissa Knight': [2008],
#  'Jeff Garlin': [2008],
#  'Fred Willard': [2008],
#  'Miyu Irino': [2016],
#  'Saori Hayami': [2016],
#  'Kensho Ono': [2016],
#  'Ryan Gosling': [2016, 2015, 2011, 2016, 2011, 2010, 2012, 2007, 2013, 2010],
#  'Emma Stone': [2016, 2011, 2009, 2011, 2010, 2012, 2014, 2013, 2008, 2013],
#  'Rosemarie DeWitt': [2016],
#  'Prabhas': [2015],
#  'Rana Daggubati': [2015],
#  'Anushka Shetty': [2015],
#  'Tamannaah Bhatia': [2015],
#  'Brad Pitt': [2009,
#   2013,
#   2015,
#   2008,
#   2014,
#   2011,
#   2007,
#   2006,
#   2010,
#   2016,
#   2013,
#   2007,
#   2011],
#  'Diane Kruger': [2009, 2009, 2016, 2011, 2013],
#  'Eli Roth': [2009],
#  'Melanie Laurent': [2009, 2013],
#  'Mads Mikkelsen': [2012],
#  'Thomas Bo Larsen': [2012],
#  'Annika Wedderkopp': [2012],
#  'Lasse Fogelstrom': [2012],
#  'Alia Shawkat': [2016, 2015],
#  'Nancy Kwan': [2016],
#  'Annabelle Attanasio': [2016],
#  'Alfred Molina': [2016, 2016, 2010],
#  'Edward Asner': [2009],
#  'Jordan Nagai': [2009],
#  'John Ratzenberger': [2009],
#  'Christopher Plummer': [2009, 2011, 2016, 2006, 2009],
#  'Tom Hanks': [2010, 2013, 2015, 2016, 2012, 2013, 2006, 2016, 2016],
#  'Tim Allen': [2010],
#  'Joan Cusack': [2010],
#  'Ned Beatty': [2010],
#  'Andrew Garfield': [2016, 2010, 2016, 2012, 2009, 2014],
#  'Sam Worthington': [2016, 2009, 2012, 2009, 2010, 2012],
#  'Luke Bracey': [2016, 2014, 2015],
#  'Teresa Palmer': [2016, 2013, 2016, 2016, 2011, 2011, 2015],
#  'Jonah Hill': [2013, 2007, 2011, 2010, 2012, 2016, 2014, 2013, 2016],
#  'Margot Robbie': [2013, 2014, 2015, 2016, 2016],
#  'Brie Larson': [2015, 2012, 2016, 2015, 2014],
#  'Jacob Tremblay': [2015, 2016, 2016],
#  'Sean Bridgers': [2015],
#  'Wendy Crewson': [2015],
#  'Nick Nolte': [2011],
#  'Joel Edgerton': [2011, 2012, 2013, 2016, 2015, 2015, 2016, 2014],
#  'Jennifer Morrison': [2011],
#  'Ivana Baquero': [2006],
#  'Ariadna Gil': [2006],
#  'Sergi Lopez': [2006],
#  'Maribel Verdu': [2006],
#  'Amy Poehler': [2015, 2015],
#  'Bill Hader': [2015, 2007, 2015],
#  'Lewis Black': [2015, 2016],
#  'Mindy Kaling': [2015],
#  'Clint Eastwood': [2008],
#  'Bee Vang': [2008],
#  'Christopher Carley': [2008],
#  'Ahney Her': [2008],
#  'Lubna Azabal': [2010],
#  'Melissa Desormeaux-Poulin': [2010],
#  'Maxim Gaudette': [2010],
#  'Mustafa Kamel': [2010],
#  'Ricardo Darin': [2009],
#  'Soledad Villamil': [2009],
#  'Pablo Rago': [2009],
#  'Carla Quevedo': [2009],
#  'Anushka Sharma': [2014],
#  'Sanjay Dutt': [2014],
#  'Boman Irani': [2014],
#  'Chris Pratt': [2014, 2014, 2012, 2016, 2015, 2016, 2011],
#  'Vin Diesel': [2014, 2011, 2015, 2013, 2009, 2013, 2015],
#  'Bradley Cooper': [2014,
#   2009,
#   2012,
#   2011,
#   2012,
#   2014,
#   2013,
#   2010,
#   2015,
#   2015,
#   2008],
#  'Zoe Saldana': [2014, 2009, 2013, 2014, 2016, 2013],
#  'Dev Patel': [2016, 2008, 2015, 2015, 2010],
#  'Nicole Kidman': [2016, 2008, 2016, 2011, 2015, 2007],
#  'Rooney Mara': [2016, 2013, 2011, 2010, 2015, 2016, 2015],
#  'Sunny Pawar': [2016],
#  'Daisy Ridley': [2015],
#  'John Boyega': [2015],
#  'Oscar Isaac': [2015, 2014, 2016],
#  'Domhnall Gleeson': [2015, 2015, 2013, 2014, 2015, 2014],
#  'Charlize Theron': [2015,
#   2016,
#   2009,
#   2012,
#   2008,
#   2015,
#   2016,
#   2012,
#   2014,
#   2016],
#  'Nicholas Hoult': [2015, 2016, 2013, 2015, 2015, 2016],
#  'Zoe Kravitz': [2015, 2016],
#  'Ginnifer Goodwin': [2016],
#  'Jason Bateman': [2016, 2007, 2009, 2015, 2011, 2008, 2014, 2016, 2009],
#  'Idris Elba': [2016, 2016, 2008, 2013, 2016, 2015],
#  'Jenny Slate': [2016],
#  'Robert Downey Jr.': [2012,
#   2016,
#   2008,
#   2007,
#   2009,
#   2011,
#   2015,
#   2014,
#   2014,
#   2013,
#   2008,
#   2010],
#  'Chris Evans': [2012, 2016, 2014, 2015, 2007, 2013, 2011, 2014, 2011],
#  'Jeremy Renner': [2012, 2016, 2010, 2008, 2015, 2011, 2007, 2012],
#  'Ben Affleck': [2014, 2012, 2010, 2016, 2016, 2016],
#  'Rosamund Pike': [2014, 2007, 2012, 2013, 2016, 2012],
#  'Neil Patrick Harris': [2014],
#  'Tyler Perry': [2014, 2016],
#  'Jake Gyllenhaal': [2013,
#   2014,
#   2007,
#   2012,
#   2016,
#   2011,
#   2015,
#   2015,
#   2013,
#   2010,
#   2010],
#  'Viola Davis': [2013, 2011, 2016, 2016, 2016, 2013, 2015],
#  'Melissa Leo': [2013, 2010, 2016],
#  'Octavia Spencer': [2011, 2016],
#  'Bryce Dallas Howard': [2011, 2011, 2015, 2016, 2016, 2006],
#  'Chiwetel Ejiofor': [2013, 2006, 2007, 2016, 2010, 2016, 2013, 2015, 2009],
#  'Michael Kenneth Williams': [2013],
#  'Michael Fassbender': [2013,
#   2011,
#   2011,
#   2016,
#   2015,
#   2011,
#   2016,
#   2012,
#   2015,
#   2010,
#   2016,
#   2013],
#  'Daniel Radcliffe': [2011, 2010, 2007, 2009, 2016, 2013, 2016, 2013, 2015],
#  'Emma Watson': [2011, 2012, 2010, 2007, 2009, 2015, 2014, 2015],
#  'Rupert Grint': [2011, 2010, 2007, 2009],
#  'Michael Gambon': [2011, 2009],
#  'Tommy Lee Jones': [2007, 2012, 2016, 2016],
#  'Javier Bardem': [2007, 2012, 2008, 2015, 2013, 2016],
#  'Josh Brolin': [2007, 2007, 2015, 2010, 2007, 2012, 2014, 2014, 2016, 2013],
#  'Woody Harrelson': [2007, 2009, 2008, 2013, 2012, 2013, 2014, 2015, 2016],
#  'Emily Mortimer': [2010, 2016, 2011],
#  'Mark Ruffalo': [2010, 2015, 2007, 2015, 2013, 2013, 2016],
#  'Ben Kingsley': [2010, 2006, 2016, 2011, 2010, 2015, 2012, 2014, 2016],
#  'Min-hee Kim': [2016],
#  'Jung-woo Ha': [2016],
#  'Jin-woong Jo': [2016],
#  'So-ri Moon': [2016],
#  'Chris Isaak': [2014],
#  'Kiefer Sutherland': [2014, 2011, 2014],
#  'C.H. Evans': [2014],
#  'Sandra Kinder': [2014],
#  'Michael Keaton': [2015, 2014, 2016, 2015, 2014],
#  'Rachel McAdams': [2015, 2013, 2011, 2016, 2009, 2011, 2015],
#  'Liev Schreiber': [2015, 2016, 2009, 2010, 2013],
#  'Emile Hirsch': [2007, 2013, 2016, 2016],
#  'Vince Vaughn': [2007, 2013, 2006, 2009],
#  'Catherine Keener': [2007, 2013, 2010],
#  'Marcia Gay Harden': [2007, 2007],
#  'Benedict Cumberbatch': [2014, 2013, 2016, 2015],
#  'Keira Knightley': [2014, 2007, 2013, 2006, 2007, 2012, 2014],
#  'Matthew Goode': [2014, 2015],
#  'Allen Leech': [2014],
#  'Ralph Fiennes': [2014, 2016, 2015, 2015, 2016, 2010, 2012],
#  'F. Murray Abraham': [2014],
#  'Mathieu Amalric': [2014, 2008],
#  'Adrien Brody': [2014, 2010],
#  'Daniel Day-Lewis': [2007, 2012],
#  'Paul Dano': [2007, 2012, 2016],
#  'Ciaran Hinds': [2007, 2008, 2016, 2013],
#  'Martin Stringer': [2007],
#  'Daniel Bruhl': [2013, 2015, 2015, 2015],
#  'Chris Hemsworth': [2013,
#   2015,
#   2011,
#   2013,
#   2012,
#   2015,
#   2016,
#   2012,
#   2015,
#   2012],
#  'Olivia Wilde': [2013, 2010, 2011],
#  'Alexandra Maria Lara': [2013],
#  'Edgar Ramirez': [2007, 2016, 2015, 2016, 2015],
#  'Joan Allen': [2007, 2009, 2008],
#  'Julia Stiles': [2007],
#  'Anne Dorval': [2014],
#  'Antoine-Olivier Pilon': [2014],
#  'Suzanne Clement': [2014],
#  'Patrick Huard': [2014],
#  'Dario Grandinetti': [2014],
#  'Maria Marull': [2014],
#  'Monica Villa': [2014],
#  'Rita Cortese': [2014],
#  'Richard Gere': [2009, 2016, 2013],
#  'Cary-Hiroyuki Tagawa': [2009],
#  'Sarah Roemer': [2009, 2007],
#  'Jay Baruchel': [2010, 2014, 2013, 2010],
#  'Gerard Butler': [2010,
#   2014,
#   2006,
#   2009,
#   2008,
#   2007,
#   2016,
#   2013,
#   2009,
#   2016,
#   2016],
#  'Christopher Mintz-Plasse': [2010, 2007, 2013, 2016],
#  'Craig Ferguson': [2010, 2014],
#  'Amy Adams': [2016, 2013, 2010, 2016, 2013, 2013, 2007, 2012, 2016],
#  'Forest Whitaker': [2016, 2015, 2013, 2014],
#  'Michael Stuhlbarg': [2016, 2016],
#  'Ryan Reynolds': [2016, 2015, 2009, 2009, 2015, 2016, 2011],
#  'Morena Baccarin': [2016],
#  'T.J. Miller': [2016, 2014, 2008, 2010, 2016, 2014],
#  'Ed Skrein': [2016],
#  'Kristen Wiig': [2015, 2013, 2013, 2011, 2016, 2016, 2016],
#  'Kate Mara': [2015, 2010, 2016, 2015, 2015],
#  'Will Poulter': [2015, 2014],
#  'Chris Pine': [2009, 2013, 2016, 2016, 2016, 2010, 2012, 2014, 2014],
#  'Zachary Quinto': [2009, 2013, 2016, 2016],
#  'Simon Pegg': [2009, 2007, 2015, 2011, 2011, 2013, 2015],
#  'Leonard Nimoy': [2009],
#  'Patrick Stewart': [2014, 2015, 2006],
#  'Ian McKellen': [2014, 2012, 2013, 2007, 2014, 2006],
#  'James McAvoy': [2014, 2011, 2007, 2016, 2016, 2013, 2013, 2008, 2015],
#  'Daniel Craig': [2006, 2011, 2012, 2015, 2008, 2007],
#  'Eva Green': [2006, 2016, 2014, 2012],
#  'Judi Dench': [2006, 2012, 2016, 2008],
#  'Jeffrey Wright': [2006, 2011, 2006],
#  'Joaquin Phoenix': [2013, 2012, 2014],
#  'Taraneh Alidoosti': [2016],
#  'Shahab Hosseini': [2016],
#  'Babak Karimi': [2016],
#  'Farid Sajjadi Hosseini': [2016],
#  'Logan Lerman': [2012, 2014, 2016, 2010, 2013, 2011],
#  'Ezra Miller': [2012, 2011, 2015],
#  'Paul Rudd': [2012, 2015, 2008, 2007, 2012],
#  'Natalie Portman': [2010, 2011, 2013, 2016, 2008, 2011, 2015, 2011],
#  'Mila Kunis': [2010, 2008, 2012, 2010, 2011, 2013, 2016, 2015],
#  'Vincent Cassel': [2010, 2013, 2016, 2016, 2015],
#  'Winona Ryder': [2010],
#  'Ferdia Walsh-Peelo': [2016],
#  'Aidan Gillen': [2016],
#  'Maria Doyle Kennedy': [2016],
#  'Jack Reynor': [2016, 2014],
#  'Jennifer Garner': [2013, 2016, 2007, 2016, 2014, 2016],
#  'Jared Leto': [2013, 2009, 2016],
#  'Steve Zahn': [2013, 2006, 2012, 2010],
#  'Freida Pinto': [2008, 2011],
#  'Saurabh Shukla': [2008],
#  'Anil Kapoor': [2008],
#  'Sharlto Copley': [2009, 2016, 2014, 2015, 2010, 2015, 2013, 2016, 2013],
#  'David James': [2009],
#  'Jason Cope': [2009],
#  'Nathalie Boltt': [2009],
#  'Brad Garrett': [2007],
#  'Lou Romano': [2007],
#  'Patton Oswalt': [2007],
#  'Ian Holm': [2007],
#  'Will Smith': [2006, 2008, 2007, 2015, 2016, 2012, 2015, 2008, 2016, 2013],
#  'Thandie Newton': [2006, 2008, 2013, 2009],
#  'Jaden Smith': [2006, 2010, 2013],
#  'Brian Howe': [2006],
#  'Djimon Hounsou': [2006, 2008],
#  'Jennifer Connelly': [2006, 2009, 2016, 2014],
#  'Kagiso Kuypers': [2006],
#  'Colin Firth': [2010, 2014, 2011, 2016, 2013],
#  'Geoffrey Rush': [2010, 2013, 2007, 2011, 2015],
#  'Helena Bonham Carter': [2010, 2007, 2015, 2010, 2016, 2012],
#  'Derek Jacobi': [2010],
#  'Felicity Jones': [2016, 2014, 2016, 2016, 2016],
#  'Diego Luna': [2016, 2014, 2016, 2016],
#  'Alan Tudyk': [2016],
#  'Donnie Yen': [2016],
#  'Casey Affleck': [2016, 2007, 2007, 2016, 2013, 2016],
#  'Michelle Williams': [2016, 2010, 2014, 2013],
#  'Kyle Chandler': [2016, 2015, 2011, 2013],
#  'Lucas Hedges': [2016],
#  'Sebastian Stan': [2016],
#  'Viggo Mortensen': [2016, 2007, 2009],
#  'George MacKay': [2016],
#  'Samantha Isler': [2016],
#  'Annalise Basso': [2016, 2016],
#  'Mario Casas': [2016],
#  'Ana Wagener': [2016],
#  'Jose Coronado': [2016],
#  'Barbara Lennie': [2016],
#  'Nick Frost': [2007, 2011, 2013],
#  'Martin Freeman': [2007, 2012, 2013, 2014, 2013, 2016],
#  'Bill Nighy': [2007, 2013, 2010, 2016, 2009],
#  'Rene Russo': [2014, 2015],
#  'Bill Paxton': [2014, 2014, 2016],
#  'Riz Ahmed': [2014, 2016],
#  'Art Parkinson': [2016, 2014],
#  'Tom Cruise': [2014, 2015, 2011, 2013, 2012, 2006, 2016, 2012],
#  'Emily Blunt': [2014, 2015, 2012, 2011, 2006, 2016, 2016, 2014],
#  'Brendan Gleeson': [2014, 2008, 2007, 2015, 2016, 2016],
#  'Gwyneth Paltrow': [2008, 2013, 2010, 2011],
#  'Terrence Howard': [2008, 2007],
#  'Jeff Bridges': [2008, 2016, 2010, 2010, 2014, 2014],
#  'Julianne Moore': [2006, 2011, 2013, 2013, 2014],
#  'Clive Owen': [2006, 2006, 2010],
#  "O'Shea Jackson Jr.": [2015],
#  'Corey Hawkins': [2015],
#  'Jason Mitchell': [2015],
#  'Neil Brown Jr.': [2015],
#  'Richard Armitage': [2012, 2013, 2014],
#  'Andy Serkis': [2012, 2014, 2011],
#  'Sam Neill': [2016, 2015],
#  'Julian Dennison': [2016],
#  'Rima Te Wiata': [2016],
#  'Rachel House': [2016, 2016],
#  'Sarah Polley': [2009],
#  'Linh Dan Pham': [2009],
#  'Ken Stott': [2013],
#  'Dave Johns': [2016],
#  'Hayley Squires': [2016],
#  'Sharon Percy': [2016],
#  'Briana Shann': [2016],
#  'Sam Rockwell': [2009, 2012, 2015],
#  'Kevin Spacey': [2009, 2008, 2006, 2016],
#  'Dominique McElligott': [2009],
#  'Rosie Shaw': [2009],
#  'Ellar Coltrane': [2014],
#  'Patricia Arquette': [2014],
#  'Ethan Hawke': [2014, 2016, 2014, 2016, 2012, 2015, 2013],
#  'Elijah Smith': [2014],
#  'Suraj Sharma': [2012],
#  'Irrfan Khan': [2012, 2012, 2016],
#  'Adil Hussain': [2012],
#  'Tabu': [2012],
#  'Colin Farrell': [2008, 2013, 2012, 2015, 2015, 2012],
#  'Elizabeth Berrington': [2008],
#  'Lee Pace': [2006],
#  'Catinca Untaru': [2006],
#  'Justine Waddell': [2006],
#  'Kim Uylenbroek': [2006],
#  'Cate Blanchett': [2014,
#   2008,
#   2006,
#   2014,
#   2013,
#   2015,
#   2015,
#   2011,
#   2010,
#   2008,
#   2015],
#  'Taraji P. Henson': [2016, 2010],
#  'Janelle Monae': [2016],
#  'Kevin Costner': [2016, 2007, 2016, 2014, 2014],
#  'Sigourney Weaver': [2009, 2016, 2015, 2014, 2016],
#  'Michelle Rodriguez': [2009, 2013, 2009, 2012, 2016],
#  'Samuel L. Jackson': [2015, 2014, 2014, 2011, 2007, 2016, 2008, 2013, 2006],
#  'Kurt Russell': [2015, 2007, 2016, 2007, 2015],
#  'Jennifer Jason Leigh': [2015, 2013],
#  'Walton Goggins': [2015],
#  'Steve Carell': [2015, 2006, 2010, 2011, 2013, 2016, 2014],
#  'Carey Mulligan': [2011, 2013, 2011],
#  'Bryan Cranston': [2011, 2012, 2016, 2016, 2016, 2014, 2012],
#  'Albert Brooks': [2011, 2016, 2015],
#  'Jennifer Lawrence': [2011,
#   2012,
#   2013,
#   2013,
#   2012,
#   2010,
#   2016,
#   2016,
#   2014,
#   2015,
#   2015],
#  'Kevin Bacon': [2011, 2010],
#  'Robert Redford': [2014, 2016],
#  'Stellan Skarsgard': [2011, 2013, 2013, 2013, 2008],
#  'Gerardo Taracena': [2006],
#  'Raoul Max Trujillo': [2006],
#  'Dalia Hernandez': [2006],
#  'Rudy Youngblood': [2006],
#  'Zach Galifianakis': [2009, 2014, 2016, 2016],
#  'Justin Bartha': [2009, 2016],
#  'Ed Helms': [2009, 2013, 2015],
#  'Edward Norton': [2014, 2006, 2016, 2008, 2012],
#  'Andrea Riseborough': [2014, 2013, 2016],
#  'Naomie Harris': [2012],
#  'Lea Seydoux': [2013, 2016, 2015],
#  'Adele Exarchopoulos': [2013, 2016],
#  'Salim Kechiouche': [2013],
#  'Aurelien Recoing': [2013],
#  'Robert De Niro': [2012, 2011, 2015, 2015, 2016, 2013, 2016, 2016],
#  'Jacki Weaver': [2012],
#  'Shailene Woodley': [2014, 2016, 2011, 2013, 2014, 2015, 2016],
#  'Ansel Elgort': [2014, 2015],
#  'Nat Wolff': [2014, 2015, 2016],
#  'Laura Dern': [2014, 2014, 2006],
#  'Lydia Wilson': [2013],
#  'Will Ferrell': [2014, 2010, 2008, 2010, 2006, 2015, 2015, 2016],
#  'Elizabeth Banks': [2014, 2008, 2012, 2006],
#  'Will Arnett': [2014, 2016, 2014],
#  'Mandy Moore': [2010],
#  'Zachary Levi': [2010],
#  'Donna Murphy': [2010],
#  'Ron Perlman': [2010, 2014, 2008, 2016, 2011],
#  'Liam Neeson': [2008, 2016, 2011, 2010, 2014, 2014, 2014, 2012, 2010, 2012],
#  'Maggie Grace': [2008, 2016, 2010, 2014],
#  'Famke Janssen': [2008, 2006, 2014],
#  'Leland Orser': [2008],
#  'Brenda Blethyn': [2007],
#  'Saoirse Ronan': [2007, 2015, 2011, 2009, 2013],
#  'Tilda Swinton': [2008, 2011, 2013, 2015],
#  'Julia Ormond': [2008],
#  'Ryan Potter': [2014],
#  'Scott Adsit': [2014],
#  'Jamie Chung': [2014],
#  'Denzel Washington': [2007, 2006, 2016, 2012, 2014, 2006, 2016, 2010, 2010],
#  'Russell Crowe': [2007, 2012, 2016, 2008, 2006, 2010, 2014],
#  'Jared Gilman': [2012],
#  'Kara Hayward': [2012],
#  'Bruce Willis': [2012, 2012, 2007, 2010],
#  'Bill Murray': [2012, 2009, 2016],
#  'Sandra Bullock': [2013, 2009, 2009, 2013, 2015],
#  'George Clooney': [2013, 2009, 2009, 2011, 2007, 2015, 2016, 2016],
#  'Ed Harris': [2013, 2007, 2013],
#  'Orto Ignatiussen': [2013],
#  'Asa Butterfield': [2008, 2011, 2016, 2013],
#  'David Thewlis': [2008, 2015],
#  'Rupert Friend': [2008],
#  "Zac Mattoon O'Brien": [2008],
#  'John C. Reilly': [2012, 2011, 2008, 2006, 2012, 2015],
#  'Jack McBrayer': [2012],
#  'Jane Lynch': [2012],
#  'Sarah Silverman': [2012, 2016],
#  'Toni Collette': [2006, 2016],
#  'Greg Kinnear': [2006],
#  'Abigail Breslin': [2006, 2009, 2013, 2015],
#  'Michael Nyqvist': [2009, 2014, 2015],
#  'Noomi Rapace': [2009, 2014, 2012, 2015, 2016],
#  'Ewa Froling': [2009],
#  'Lena Endre': [2009],
#  'Alia Bhatt': [2016],
#  'Shah Rukh Khan': [2016],
#  'Kunal Kapoor': [2016],
#  'Priyanka Moodley': [2016],
#  'Barkhad Abdi': [2013, 2015],
#  'Barkhad Abdirahman': [2013],
#  'Gaspard Schlatter': [2016],
#  'Sixtine Murat': [2016],
#  'Paulin Jaccoud': [2016],
#  'Michel Vuillermoz': [2016],
#  'Meryl Streep': [2009, 2016, 2006, 2014, 2008, 2014],
#  'Jason Schwartzman': [2009, 2006],
#  'Sally Hawkins': [2016, 2013],
#  'Kari Matchett': [2016],
#  'Zachary Bennett': [2016],
#  'Jim Sturgess': [2013, 2007, 2011, 2008, 2008],
#  'Sylvia Hoeks': [2013],
#  'Donald Sutherland': [2013, 2008],
#  'Angelina Jolie': [2008, 2008, 2016, 2014, 2008, 2010, 2007],
#  'Colm Feore': [2008],
#  'Amy Ryan': [2008, 2015, 2016, 2016],
#  'Gattlin Griffith': [2008],
#  'Thomas Mann': [2015, 2012],
#  'RJ Cyler': [2015],
#  'Olivia Cooke': [2015],
#  'Nick Offerman': [2015, 2016, 2013, 2014],
#  'Josh Hartnett': [2006],
#  'Morgan Freeman': [2006, 2007, 2010, 2013, 2008, 2013, 2014, 2014, 2016],
#  'Lucy Liu': [2006],
#  "Auli'i Cravalho": [2016],
#  'Dwayne Johnson': [2016,
#   2011,
#   2015,
#   2013,
#   2013,
#   2010,
#   2016,
#   2015,
#   2014,
#   2013],
#  'Temuera Morrison': [2016],
#  'Taron Egerton': [2014, 2016, 2015],
#  'Ben Foster': [2016, 2013, 2016, 2009, 2016, 2016],
#  'Gil Birmingham': [2016, 2011],
#  'Alicia Vikander': [2014, 2015, 2016, 2015, 2016, 2014],
#  'Sonoya Mizuno': [2014],
#  'Lena Headey': [2006, 2012, 2014, 2015, 2013],
#  'David Wenham': [2006],
#  'Dominic West': [2006, 2016, 2010],
#  'Aaron Taylor-Johnson': [2010, 2016, 2013, 2012, 2012, 2014],
#  'Nicolas Cage': [2010, 2007, 2016],
#  'Chloe Grace Moretz': [2010,
#   2009,
#   2011,
#   2014,
#   2010,
#   2014,
#   2013,
#   2015,
#   2013,
#   2016,
#   2016],
#  'Garrett M. Brown': [2010],
#  'Anthony Edwards': [2007],
#  'Lily James': [2016, 2015, 2016],
#  'Jai Courtney': [2016, 2014, 2015, 2015],
#  'Lois van Wijk': [2016],
#  'Quinton Aaron': [2009],
#  'Tim McGraw': [2009],
#  'Jae Head': [2009, 2008],
#  'Jesse Eisenberg': [2010, 2009, 2013, 2011, 2016, 2016, 2016, 2012],
#  'Justin Timberlake': [2010, 2011, 2011, 2016],
#  'Charlie Cox': [2007],
#  'Claire Danes': [2007],
#  'Sienna Miller': [2007, 2014, 2016, 2015, 2015],
#  'Owen Wilson': [2011, 2006, 2015, 2014, 2013, 2014, 2011, 2016, 2016],
#  'Kathy Bates': [2011],
#  'Kurt Fuller': [2011],
#  'Eddie Redmayne': [2014, 2016, 2015, 2015],
#  'Tom Prior': [2014],
#  'Sophie Perry': [2014],
#  'Jason Segel': [2010, 2008, 2014],
#  'Russell Brand': [2010],
#  'Julie Andrews': [2010],
#  'Dakota Fanning': [2009, 2016, 2016],
#  'Teri Hatcher': [2009],
#  'John Hodgman': [2009],
#  'Jennifer Saunders': [2009],
#  'John Goodman': [2012, 2016, 2013, 2012, 2016, 2014],
#  'Alan Arkin': [2012],
#  'Giuseppe Battiston': [2016],
#  'Anna Foglietta': [2016],
#  'Marco Giallini': [2016],
#  'Edoardo Leo': [2016],
#  'Zooey Deschanel': [2009, 2007, 2016, 2008],
#  'Geoffrey Arend': [2009],
#  'Naomi Watts': [2007, 2012, 2015, 2016, 2007, 2013, 2015, 2016, 2016],
#  'Armin Mueller-Stahl': [2007],
#  'Josef Altin': [2007],
#  'Michelle Monaghan': [2007, 2011, 2016, 2006, 2014, 2008, 2007, 2015],
#  'Rosario Dawson': [2008, 2007, 2013, 2010, 2008, 2011],
#  'Michael Ealy': [2008, 2012],
#  'Eddie Murphy': [2016],
#  'Britt Robertson': [2016, 2015, 2012, 2015],
#  'Natascha McElhone': [2016],
#  'Xavier Samuel': [2016, 2016, 2013, 2010],
#  'Rolf Lassgard': [2015],
#  'Bahar Pars': [2015],
#  'Filip Berg': [2015],
#  'Ida Engvoll': [2015],
#  'Seth Rogen': [2011,
#   2015,
#   2007,
#   2008,
#   2011,
#   2013,
#   2014,
#   2008,
#   2014,
#   2016,
#   2016],
#  'Anna Kendrick': [2011,
#   2012,
#   2016,
#   2009,
#   2012,
#   2016,
#   2015,
#   2016,
#   2015,
#   2016,
#   2014],
#  'Michael Pena': [2012, 2014, 2007, 2016, 2016],
#  'America Ferrera': [2012],
#  'Benedict Wong': [2016],
#  'Jackie Earle Haley': [2009],
#  'Patrick Wilson': [2009, 2013, 2016, 2015, 2010, 2015, 2016],
#  'Carla Gugino': [2009, 2015],
#  'Malin Akerman': [2009, 2007, 2009, 2016],
#  'Michael Cera': [2007, 2010, 2007],
#  'Benicio Del Toro': [2015, 2012],
#  'Jon Bernthal': [2015, 2016, 2010],
#  'Keri Russell': [2014, 2007, 2016],
#  'Kodi Smit-McPhee': [2014, 2009, 2010],
#  'Shia LaBeouf': [2014,
#   2012,
#   2007,
#   2016,
#   2013,
#   2007,
#   2008,
#   2011,
#   2008,
#   2009,
#   2015],
#  'Amanda Seyfried': [2012, 2011, 2008, 2015, 2014, 2009],
#  'James Franco': [2011, 2010, 2008, 2013, 2014, 2016, 2013, 2016, 2011],
#  'Karin Konoval': [2011],
#  'Jude Law': [2009, 2011, 2015, 2012, 2011, 2016],
#  'Mark Strong': [2009, 2012, 2016, 2016, 2011, 2008, 2016, 2011],
#  'Michael B. Jordan': [2015, 2014, 2015],
#  'Sylvester Stallone': [2015, 2006, 2008, 2013, 2012, 2010, 2014],
#  'Tessa Thompson': [2015, 2014, 2016],
#  'Phylicia Rashad': [2015],
#  'Jemaine Clement': [2014, 2012, 2016],
#  'Taika Waititi': [2014],
#  'Cori Gonzalez-Macuer': [2014],
#  'Jonny Brugh': [2014],
#  'Mark Rylance': [2015, 2016],
#  'Alan Alda': [2015, 2015],
#  'Ewan McGregor': [2012, 2010, 2016],
#  'Tom Holland': [2012, 2016],
#  'Oaklee Pendergast': [2012],
#  'Rebecca Hall': [2010, 2015, 2008, 2016, 2014, 2013],
#  'Jon Hamm': [2010, 2015, 2016],
#  'Josh Hutcherson': [2013, 2012, 2007, 2014, 2015, 2012],
#  'Liam Hemsworth': [2013, 2012, 2015, 2014, 2015, 2012, 2016],
#  'Philip Seymour Hoffman': [2013, 2011, 2012, 2006],
#  'Robin Wright': [2011, 2013, 2007],
#  'Sandra Huller': [2016],
#  'Peter Simonischek': [2016],
#  'Michael Wittenborn': [2016],
#  'Thomas Loibl': [2016],
#  'Anthony Mackie': [2008, 2011, 2009, 2013, 2016],
#  'Brian Geraghty': [2008],
#  'Guy Pearce': [2008, 2012, 2013, 2016],
#  'Stuart Graham': [2008],
#  'Laine Megaw': [2008],
#  'Brian Milligan': [2008],
#  'Liam McMahon': [2008],
#  'Emmanuel Garijo': [2016],
#  'Tom Hudson': [2016],
#  'Baptiste Goy': [2016],
#  'Axel Devillers': [2016],
#  'Jessica Biel': [2006, 2010, 2016],
#  'Paul Giamatti': [2006, 2014, 2006],
#  'Rufus Sewell': [2006],
#  'Hailee Steinfeld': [2010, 2016, 2013, 2013, 2015, 2014],
#  'Jodie Foster': [2006, 2013],
#  'Amber Tamblyn': [2010],
#  'Sean Bott': [2010],
#  'Rose McGowan': [2007, 2007, 2011],
#  'Danny Trejo': [2007],
#  'Zoe Bell': [2007, 2007],
#  'Jack Black': [2008, 2016, 2008, 2015],
#  'Ian McShane': [2008, 2011, 2008, 2014],
#  'Dustin Hoffman': [2008, 2006, 2014, 2016],
#  'Antonio Banderas': [2011, 2014],
#  'Elena Anaya': [2011],
#  'Jan Cornet': [2011],
#  'Marisa Paredes': [2011],
#  'Katherine Waterston': [2016, 2014],
#  'Alison Sudol': [2016],
#  'Dan Fogler': [2016, 2011],
#  'Michael Shannon': [2016, 2013, 2016],
#  'Mahershala Ali': [2016, 2016],
#  'Shariff Earp': [2016],
#  'Duan Sanderson': [2016],
#  'Alex R. Hibbert': [2016],
#  'Laura Linney': [2016, 2016, 2016],
#  'Valerie Mahaffey': [2016],
#  "Beverly D'Angelo": [2016],
#  "Jason O'Mara": [2016, 2016],
#  'Lewis MacDougall': [2016],
#  'Toby Kebbell': [2016, 2016],
#  'Neel Sethi': [2016],
#  'Mary Elizabeth Winstead': [2010, 2016, 2016],
#  'Kieran Culkin': [2010],
#  'Alison Pill': [2010],
#  'Kristen Bell': [2013, 2008, 2016, 2016],
#  'Idina Menzel': [2013],
#  'Jonathan Groff': [2013],
#  'Josh Gad': [2013, 2016],
#  'Garance Marillier': [2016],
#  'Ella Rumpf': [2016],
#  'Rabah Nait Oufella': [2016],
#  'Laurent Lucas': [2016, 2016],
#  'Adam Driver': [2016, 2016, 2013, 2016],
#  'Golshifteh Farahani': [2016, 2008],
#  'Nellie': [2016],
#  'Rizwan Manji': [2016],
#  'Vera Farmiga': [2013, 2011, 2016, 2014, 2009, 2009],
#  'Ron Livingston': [2013],
#  'Lili Taylor': [2013],
#  'Halle Berry': [2012, 2006],
#  'Hugh Grant': [2012, 2016],
#  'Hugo Weaving': [2012, 2015, 2011],
#  'Yoo Gong': [2016, 2016],
#  'Soo-an Kim': [2016],
#  'Yu-mi Jung': [2016],
#  'Dong-seok Ma': [2016],
#  'Taylor Kitsch': [2013, 2012, 2012],
#  'Emory Cohen': [2015, 2016, 2016],
#  'Jim Broadbent': [2015, 2016, 2013],
#  'Sarah Snook': [2014],
#  'Noah Taylor': [2014],
#  'Madeleine West': [2014],
#  'Jared Harris': [2011, 2016, 2016],
#  'Sam Shepard': [2007],
#  'Mary-Louise Parker': [2007, 2010],
#  'Pierre Niney': [2016, 2016],
#  'Paula Beer': [2016],
#  'Ernst Stotzner': [2016],
#  'Marie Gruber': [2016],
#  'Jasper Newell': [2011],
#  'Christopher Lee': [2011],
#  'Freddie Highmore': [2007],
#  'Jonathan Rhys Meyers': [2007],
#  'Adrian Titieni': [2016],
#  'Maria-Victoria Dragus': [2016],
#  'Lia Bugnar': [2016],
#  'Malina Manovici': [2016],
#  'Chadwick Boseman': [2013, 2016],
#  'T.R. Knight': [2013],
#  'Harrison Ford': [2013, 2015, 2013, 2008],
#  'Nicole Beharie': [2013],
#  'Hilary Swank': [2007, 2007],
#  'Imelda Staunton': [2007],
#  'Patrick Dempsey': [2007, 2007],
#  'Scott Glenn': [2007, 2012],
#  'Emma Thompson': [2013, 2012, 2013],
#  'Annie Rose Buckley': [2013],
#  'Gael Garcia Bernal': [2006],
#  'Mohamed Akhzam': [2006],
#  'Jun Kunimura': [2016],
#  'Jung-min Hwang': [2016],
#  'Do-won Kwak': [2016],
#  'Woo-hee Chun': [2016],
#  'Ben Whishaw': [2006, 2015, 2015, 2016],
#  'Alan Rickman': [2006, 2007, 2015],
#  'Francesc Albiol': [2006],
#  'David Oyelowo': [2014, 2016, 2016],
#  'Carmen Ejogo': [2014],
#  'Tim Roth': [2014, 2008, 2015, 2007, 2015],
#  'Lorraine Toussaint': [2014],
#  'Emilia Clarke': [2016, 2015],
#  'Sam Claflin': [2016, 2014, 2016, 2012],
#  'Janet McTeer': [2016],
#  'Charles Dance': [2016],
#  'Angourie Rice': [2016],
#  'Matt Bomer': [2016, 2015],
#  'Ellen DeGeneres': [2016],
#  "Ed O'Neill": [2016],
#  'Kaitlin Olson': [2016],
#  'Scott Adkins': [2016],
#  'Teodora Duhovnikova': [2016],
#  'Alon Aboutboul': [2016],
#  'Julian Vergov': [2016],
#  'Haley Lu Richardson': [2016, 2016],
#  'Blake Jenner': [2016, 2016],
#  'Kyra Sedgwick': [2016],
#  'Madison Wolfe': [2016],
#  "Frances O'Connor": [2016],
#  'Rebecca Ferguson': [2015, 2016, 2016],
#  'Annette Bening': [2016],
#  'Elle Fanning': [2016, 2011, 2014, 2016, 2016, 2016],
#  'Greta Gerwig': [2016, 2016],
#  'Billy Crudup': [2016, 2015, 2016],
#  'Luke Treadaway': [2016],
#  'Bob the Cat': [2016],
#  'Ruta Gedmintas': [2016],
#  'Joanne Froggatt': [2016],
#  'Sally Field': [2012, 2015],
#  'David Strathairn': [2012, 2007],
#  'Clemence Poesy': [2016],
#  'Antoine Bertrand': [2016],
#  'Ashley Walters': [2016],
#  'Oona Laurence': [2015, 2016],
#  'Paula Patton': [2011, 2009, 2016, 2006, 2016],
#  'John Doman': [2010],
#  'Faith Wladyka': [2010],
#  'Tom Costello': [2016],
#  'Jo Hartley': [2016],
#  'Leslie Bibb': [2009, 2008],
#  'Colm Meaney': [2009],
#  'Anna Friel': [2011],
#  'Abbie Cornish': [2011, 2006, 2015, 2014, 2011, 2016],
#  "Fionn O'Shea": [2016],
#  'Nicholas Galitzine': [2016],
#  'Andrew Scott': [2016, 2013, 2016, 2016, 2015],
#  'Moe Dunford': [2016],
#  'Johnny Depp': [2007,
#   2006,
#   2007,
#   2009,
#   2015,
#   2011,
#   2010,
#   2013,
#   2014,
#   2016,
#   2012,
#   2016],
#  'Timothy Spall': [2007, 2016],
#  'Robert Duvall': [2014, 2009],
#  'Billy Bob Thornton': [2014, 2010],
#  'Benjamin Bratt': [2013],
#  'Miranda Cosgrove': [2013],
#  'Mia Wasikowska': [2011, 2015, 2010, 2016],
#  'Jamie Bell': [2011, 2013, 2013, 2013, 2012, 2008, 2015],
#  'Su Elliot': [2011],
#  'Adam Levine': [2013],
#  'Madina Nalwanga': [2016],
#  "Lupita Nyong'o": [2016],
#  'Martin Kabanza': [2016],
#  'Evan Rachel Wood': [2007, 2015],
#  'Joe Anderson': [2007, 2013],
#  'Dana Fuchs': [2007],
#  'Anya Taylor-Joy': [2016, 2015, 2016],
#  'Jessica Sula': [2016],
#  'Gugu Mbatha-Raw': [2016, 2016, 2016],
#  'Tadanobu Asano': [2016],
#  'Orlando Bloom': [2006, 2007],
#  'Jack Davenport': [2006, 2016],
#  'Henry Cavill': [2015, 2013, 2016, 2011],
#  'Armie Hammer': [2015, 2016, 2013, 2016],
#  'Elizabeth Debicki': [2015],
#  'Stephen Henderson': [2016],
#  'Jovan Adepo': [2016],
#  'Eva Mendes': [2012, 2010, 2007],
#  'Craig Van Hook': [2012],
#  'Tobey Maguire': [2013, 2007],
#  'Helen Mirren': [2015, 2013, 2015, 2010],
#  'Katie Holmes': [2015],
#  'John Krasinski': [2016],
#  'Pablo Schreiber': [2016],
#  'James Badge Dale': [2016, 2011, 2013, 2016],
#  'David Denman': [2016, 2013],
#  'Michael Douglas': [2015],
#  'Corey Stoll': [2015, 2016],
#  'Evangeline Lilly': [2015, 2011],
#  'Christos Stergioglou': [2009],
#  'Michele Valley': [2009],
#  'Angeliki Papoulia': [2009],
#  'Hristos Passalis': [2009],
#  'Common': [2013],
#  'Paul Walker': [2011, 2015, 2013, 2009],
#  'Jordana Brewster': [2011, 2009],
#  'Tom Wilkinson': [2008, 2016, 2016, 2013],
#  'Kyle Gallner': [2014, 2014],
#  'Cole Konis': [2014],
#  'Florence Pugh': [2016],
#  'Christopher Fairbank': [2016],
#  'Cosmo Jarvis': [2016],
#  'Naomi Ackie': [2016],
#  'Billy Crystal': [2013],
#  'Steve Buscemi': [2013],
#  'Kate Winslet': [2008, 2015, 2015, 2016, 2014, 2011, 2015],
#  'Christopher Fitzgerald': [2008],
#  'Jonathan Roumie': [2008],
#  'Harvey Keitel': [2015],
#  'Rachel Weisz': [2015, 2006, 2016, 2015, 2012, 2009, 2016, 2013],
#  'Jane Fonda': [2015, 2013],
#  'Jim Carrey': [2016, 2013, 2016],
#  'Charlotte Gainsbourg': [2016, 2016, 2011, 2013, 2013, 2009],
#  'Marton Csokas': [2016, 2014],
#  'Kati Outinen': [2016],
#  'Cillian Murphy': [2007, 2016, 2016, 2015, 2011, 2014],
#  'Rose Byrne': [2007, 2015, 2007, 2011, 2010, 2014, 2013, 2016, 2014],
#  'Michelle Yeoh': [2007, 2016, 2008],
#  'Tina Fey': [2010, 2016, 2015],
#  'Ben Stiller': [2013, 2008, 2014, 2007, 2016],
#  'Jon Daly': [2013],
#  'Kathryn Hahn': [2013, 2016, 2016],
#  'Shameik Moore': [2015],
#  'Tony Revolori': [2015, 2016],
#  'Kiersey Clemons': [2015],
#  'Kimberly Elise': [2015],
#  'Jason Clarke': [2012, 2015, 2010, 2009, 2015, 2013],
#  'Michael Pitt': [2014, 2007],
#  'Steven Yeun': [2014],
#  'Astrid Berges-Frisbey': [2014],
#  'Brit Marling': [2014],
#  'Channing Tatum': [2014,
#   2012,
#   2014,
#   2006,
#   2013,
#   2006,
#   2012,
#   2011,
#   2009,
#   2013,
#   2015,
#   2015],
#  'Jon Favreau': [2014, 2006, 2009],
#  'Aaron Paul': [2015, 2014, 2016, 2016],
#  'Sean Patrick Thomas': [2006],
#  'Ellen Burstyn': [2006, 2016],
#  'Demi Moore': [2007],
#  'William Hurt': [2007, 2008],
#  'Dane Cook': [2007],
#  'Jeremy Davies': [2006],
#  'Zach Grenier': [2006],
#  'Nadine Velazquez': [2012, 2016],
#  'Don Cheadle': [2012, 2013, 2010],
#  'Alec Baldwin': [2013, 2015, 2012, 2016],
#  'Peter Sarsgaard': [2013, 2009, 2016, 2011],
#  'Gabourey Sidibe': [2009],
#  "Mo'Nique": [2009],
#  'Mariah Carey': [2009],
#  'Jamie Dornan': [2016, 2016, 2016, 2015],
#  'Michael McElhatton': [2016, 2016],
#  'Amara Miller': [2011],
#  'Nick Krause': [2011],
#  'Charlotte Le Bon': [2015, 2016, 2016, 2016, 2016],
#  'Guillaume Baillargeon': [2015],
#  'Emilie Leclerc': [2015],
#  'Reese Witherspoon': [2016, 2014, 2012, 2013],
#  'Seth MacFarlane': [2016, 2012, 2015, 2014],
#  'John Carroll Lynch': [2016],
#  'Linda Cardellini': [2016, 2015],
#  'Keanu Reeves': [2014, 2016, 2016, 2016, 2015, 2016],
#  'Alfie Allen': [2014],
#  'Willem Dafoe': [2014, 2016, 2013, 2012, 2009, 2016],
#  'Stephen Lang': [2016, 2011],
#  'Jane Levy': [2016, 2013, 2016],
#  'Dylan Minnette': [2016, 2015, 2014],
#  'Daniel Zovatto': [2016],
#  'Douglas M. Griffin': [2016, 2016],
#  'James DuMont': [2016],
#  'Jason Statham': [2015, 2015, 2010, 2008, 2014, 2016],
#  'John Gallagher Jr.': [2016, 2016, 2016],
#  'Stanley Tucci': [2012, 2014],
#  'Florence Clery': [2016],
#  'Ice Cube': [2012, 2014, 2016],
#  'Brittany Snow': [2012, 2015],
#  'Rebel Wilson': [2012, 2015, 2016, 2016],
#  'Anna Camp': [2012],
#  'David Harbour': [2014, 2014],
#  'Jeff Daniels': [2015, 2016],
#  'Blake Lively': [2015, 2016, 2012, 2016, 2011],
#  'Michiel Huisman': [2015, 2014, 2015],
#  'Kathy Baker': [2015],
#  'Isabelle Huppert': [2016, 2016],
#  'Laurent Lafitte': [2016],
#  'Anne Consigny': [2016],
#  'Charles Berling': [2016],
#  'Lucy Walters': [2011],
#  'Alice Braga': [2007, 2013, 2010],
#  'Charlie Tahan': [2007],
#  'Salli Richardson-Whitfield': [2007],
#  'Sarah Paulson': [2015],
#  'Rhona Mitra': [2007, 2009],
#  'Danny Glover': [2007],
#  'Brian Caspe': [2016],
#  'Karel Hermanek Jr.': [2016],
#  'Cynthia Nixon': [2016, 2008, 2010],
#  'Jennifer Ehle': [2016, 2015],
#  'Duncan Duff': [2016],
#  'Keith Carradine': [2016],
#  'Pierce Brosnan': [2010, 2015, 2008, 2016],
#  'Olivia Williams': [2010],
#  "Jack O'Connell": [2014, 2016],
#  'Miyavi': [2014],
#  'Garrett Hedlund': [2014, 2010, 2016, 2015],
#  'Kelly Macdonald': [2012],
#  'Billy Connolly': [2012],
#  'Julie Walters': [2012],
#  'Richard Jenkins': [2010, 2015, 2012, 2008, 2016],
#  'Cara Buono': [2010],
#  'John Hawkes': [2010],
#  'Garret Dillahunt': [2010],
#  'Isaiah Stone': [2010],
#  'Thomas Jane': [2007, 2016, 2016],
#  'Laurie Holden': [2007, 2006],
#  'Andre Braugher': [2007],
#  'Lily Collins': [2014, 2013, 2016],
#  'Christian Cooke': [2014],
#  'Jaime Winstone': [2014],
#  'Byung-hun Lee': [2016, 2013],
#  'Kang-ho Song': [2016, 2006],
#  'Ji-min Han': [2016],
#  'Justin Long': [2007, 2014, 2016],
#  'Timothy Olyphant': [2007, 2011],
#  'Maggie Q': [2007],
#  'Anthony Hopkins': [2007, 2011, 2015, 2014, 2016],
#  'Jeremy Irons': [2015, 2006, 2016, 2015],
#  'Malcolm Sinclair': [2015],
#  'Raghuvir Joshi': [2015],
#  'Christopher Walken': [2012],
#  'Antonio Tarver': [2006],
#  'Milo Ventimiglia': [2006],
#  'Burt Young': [2006],
#  'Robert Pattinson': [2010, 2016, 2012, 2008, 2011, 2010],
#  'Emilie de Ravin': [2010, 2006],
#  'Caitlyn Rund': [2010],
#  'Moises Acevedo': [2010],
#  'AnnaSophia Robb': [2007],
#  'Robert Patrick': [2007, 2014],
#  'Emily Baldoni': [2013],
#  'Maury Sterling': [2013],
#  'Nicholas Brendon': [2013],
#  'Elizabeth Gracen': [2013],
#  'Oprah Winfrey': [2013, 2009],
#  'John Cusack': [2013, 2007, 2009],
#  'Nick Robinson': [2013],
#  'Gabriel Basso': [2013, 2016, 2016],
#  'Moises Arias': [2013],
#  'Charlie Hunnam': [2016, 2013, 2015],
#  'John Francis Daley': [2007],
#  'Austin Pendleton': [2007],
#  'Colleen Camp': [2007],
#  'Neil Flynn': [2007],
#  'Karl Urban': [2016, 2012, 2013, 2014],
#  'Marion Cotillard': [2016, 2016, 2006, 2015, 2016],
#  'Vincent Ebrahim': [2016],
#  'Steve Lantz': [2016],
#  'Gregg Weiner': [2016],
#  'Kit Harington': [2016, 2014],
#  'Carice van Houten': [2016],
#  'Megan Fox': [2007, 2016, 2009, 2014, 2009],
#  'Josh Duhamel': [2007, 2013, 2010, 2011, 2009],
#  'Tyrese Gibson': [2007, 2008, 2011, 2009],
#  'Bonnie Hunt': [2006],
#  'Paul Newman': [2006],
#  'Larry the Cable Guy': [2006, 2011],
#  'Jessica Barden': [2015],
#  'Olivia Colman': [2015, 2013],
#  'Melissa McCarthy': [2015, 2013, 2016, 2016],
#  'Lior Ashkenazi': [2016],
#  'Michael Sheen': [2016, 2016, 2009],
#  'Vanessa Ferlito': [2007],
#  'Diane Lane': [2013, 2016],
#  'John Leguizamo': [2016, 2016, 2008],
#  'Judy Davis': [2015, 2006],
#  'Antonia Ribero': [2016],
#  'Ang Phula Sherpa': [2015],
#  'Thomas M. Wright': [2015],
#  'Martin Henderson': [2015, 2016],
#  'Kelly Adams': [2008],
#  'Luing Andrews': [2008],
#  'Katy Barker': [2008],
#  'Eddie Marsan': [2013],
#  'Imogen Poots': [2013, 2015, 2014, 2014],
#  'Scott Eastwood': [2015, 2013],
#  'Jack Huston': [2015, 2016, 2016, 2016],
#  'Olivia Thirlby': [2012, 2015],
#  'Rachel Wood': [2012],
#  'AJ Michalka': [2011],
#  'Joel Courtney': [2011],
#  'Matthew Fox': [2015],
#  'Amanda Bynes': [2010, 2006],
#  'Penn Badgley': [2010],
#  'Dan Byrd': [2010, 2006],
#  'Harry Connick Jr.': [2007],
#  'Lisa Kudrow': [2007, 2014],
#  'Ruth Negga': [2016],
#  'Will Dalton': [2016],
#  'Dean Mumford': [2016],
#  'Richenda Carey': [2015],
#  'Allison Tolman': [2015],
#  'Susan Sarandon': [2007, 2009],
#  'James Marsden': [2007, 2014, 2014, 2006],
#  'Anders Holm': [2015],
#  'James Gandolfini': [2014],
#  'Matthias Schoenaerts': [2014, 2015],
#  'Andre Marcon': [2016],
#  'Roman Kolinka': [2016],
#  'Edith Scob': [2016],
#  'Lisa Thoreson': [2011],
#  'Florence Kastriner': [2011],
#  'Gaby Hoffmann': [2014],
#  'Kirsten Dunst': [2011, 2016, 2006, 2010, 2007],
#  'Alexander Skarsgard': [2011, 2016, 2016, 2012],
#  'Anika Noni Rose': [2009, 2013],
#  'Keith David': [2009],
#  'Bruno Campos': [2009],
#  'Christopher Evan Welch': [2008],
#  'Ruth Wilson': [2013, 2016],
#  'Dakota Goyo': [2011],
#  'Julie Benz': [2008],
#  'Matthew Marsden': [2008],
#  'Graham McTavish': [2008],
#  'Freddy Rodriguez': [2007],
#  'Marley Shelton': [2007],
#  'David Morse': [2015, 2007],
#  'Jesse Plemons': [2012],
#  'Morjana Alaoui': [2008],
#  'Mylene Jampanoi': [2008],
#  'Catherine Begin': [2008],
#  'Robert Toupin': [2008],
#  'Logan Marshall-Green': [2012, 2015],
#  'Laurence Fishburne': [2016, 2010],
#  'Gemma Arterton': [2016, 2016, 2010],
#  'Ty Simpkins': [2015, 2010],
#  'Judy Greer': [2015, 2010],
#  'Travis Fimmel': [2016],
#  ...}

# %%
def maximum_gap_of_years(actor: str):
    assert actor in actor_year.keys(), 'This actor seems not to be in the IMDB list'
    return max(actor_year[actor]) - min(actor_year[actor])

#maximum_gap_of_years('Leonardo DiCaprio')

# %%
actors_maximum_gap_of_years = {}
for actor in actor_year.keys():
    actors_maximum_gap_of_years[actor] = maximum_gap_of_years(actor)
actors_maximum_gap_of_years = {k: v for k, v in sorted(actors_maximum_gap_of_years.items(), key=lambda item: item[1], reverse=True)}
#actors_maximum_gap_of_years

# %%
print(f'Actors whose movies lead to the largest maximum gap of years(10 years):\n{[i for i, j in actors_maximum_gap_of_years.items() if j == 10]}\n')
# Out:
# Actors whose movies lead to the largest maximum gap of years(10 years):
# ['Christian Bale', 'Anne Hathaway', 'Hugh Jackman', 'Scarlett Johansson', 'Matt Damon', 'Mark Wahlberg', 'Brad Pitt', 'Christopher Plummer', 'Tom Hanks', 'Bryce Dallas Howard', 'Chiwetel Ejiofor', 'Ben Kingsley', 'Gerard Butler', 'Eva Green', 'Judi Dench', 'Will Smith', 'Jennifer Connelly', 'Tom Cruise', 'Emily Blunt', 'Kevin Spacey', 'Samuel L. Jackson', 'Steve Carell', 'Edward Norton', 'Will Ferrell', 'Denzel Washington', 'Russell Crowe', 'Toni Collette', 'Meryl Streep', 'Morgan Freeman', 'Dominic West', 'Owen Wilson', 'Michelle Monaghan', 'Jessica Biel', 'Dustin Hoffman', 'Ben Whishaw', 'Paula Patton', 'Abbie Cornish', 'Johnny Depp', 'Jack Davenport', 'Rachel Weisz', 'Ellen Burstyn', 'Kang-ho Song', 'Jeremy Irons', 'Marion Cotillard', 'Kirsten Dunst', 'Jennifer Aniston', 'Justin Theroux', 'Maya Rudolph', 'Kate Bosworth', 'Audrey Tautou', 'Luke Wilson', 'Sacha Baron Cohen', 'Bob Balaban']

# %% [markdown]
# # (7) Find all actors who collaborate with Johnny Depp in direct and indirect ways

# %%
for i in actors:
    j = i.split(',')
    if 'Johnny Depp' in j:
        print(j)
