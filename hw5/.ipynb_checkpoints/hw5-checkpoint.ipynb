# %%
import numpy as np
import pandas as pd
import missingno as msn
import tensorflow
import keras
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_train = pd.read_csv('churn_prediction_data/train.csv')
df_test = pd.read_csv('churn_prediction_data/test.csv')

# %%
msn.matrix(df_train), msn.matrix(df_test)
# Out:
# (<AxesSubplot:>, <AxesSubplot:>)

# %%
df_train.head(3)
# Out:
#    RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0        551    15806307  Trevisano          720     Spain    Male   38
# 1       6897    15709621     Martin          682    France  Female   54
# 2       4588    15619340     Palmer          672    France  Female   31
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       5  114051.97              2          0               1
# 1       4   62397.41              1          1               0
# 2       5  119903.67              1          1               1
#
#    EstimatedSalary  Exited
# 0        107577.29       0
# 1        113088.60       1
# 2        132925.17       0

# %%
df_test.head(3)
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0       2209    15623595     Scott          726    France  Female   39
# 1       9924    15740283  Yegorova          661    France    Male   42
# 2       4617    15802368       Tan          545    France    Male   34
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       3   62397.41              1          0               0
# 1       3  130339.64              1          1               0
# 2       6   62397.41              2          1               1
#
#    EstimatedSalary
# 0        106139.31
# 1        125776.38
# 2         78372.28

# %%
print('train:', len(df_train), ',', 'test:', len(df_test))
# Out:
# train: 8000 , test: 2000

# %%
print(df_train.columns)
print(df_test.columns)
# Out:
# Index(['RowNumber', 'CustomerId', 'Surname', 'CreditScore', 'Geography',
#        'Gender', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard',
#        'IsActiveMember', 'EstimatedSalary', 'Exited'],
#       dtype='object')
# Index(['RowNumber', 'CustomerId', 'Surname', 'CreditScore', 'Geography',
#        'Gender', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard',
#        'IsActiveMember', 'EstimatedSalary'],
#       dtype='object')

# %%
x_train = df_train.loc[:, 'RowNumber': 'EstimatedSalary']
x_test = df_test.loc[:, 'RowNumber': 'EstimatedSalary']

# %%
fig, axes = plt.subplots(1, 2, figsize=(20, 5), sharex=True, sharey=True)
#fig.suptitle('')

sns.heatmap(x_train.corr(), ax=axes[0], annot=True)
axes[0].set_title('x_train')

sns.heatmap(x_test.corr(), ax=axes[1], annot=True)
axes[1].set_title('x_test')
# Out:
# Text(0.5, 1.0, 'x_test')

# %%
df_train.Exited.unique()
# Out:
# array([0, 1])

# %%
df_train.Exited.value_counts()
# Out:
# 0    6368
# 1    1632
# Name: Exited, dtype: int64
